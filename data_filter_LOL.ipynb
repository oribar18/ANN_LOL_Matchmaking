# %%
import numpy as np
import pandas as pd

# %%
#read csv
players_data = pd.read_csv('league_of_graphs_players.csv')

games_players_data = pd.read_csv('games_players_data.csv')

games_data = pd.read_csv('Games_data_raw.csv')

# %%
players_data.dropna(subset=['winrate'], inplace=True)

bad_names = []
for index, row in games_players_data.iterrows():
    if row['winrate'] is np.nan:
        bad_names.append(row['username'])
games_players_data.dropna(subset=['winrate'], inplace=True)
print(bad_names)
# Out:
# ['sparck#gado', 'sparck#gado', 'sparck#gado', 'e7c3c0fd-cee3-4399-877b-baf89c9f6f46#EUW', 'YeQiuFengXXX#dddd', 'e7c3c0fd-cee3-4399-877b-baf89c9f6f46#EUW', 'sparck#gado', 'e7c3c0fd-cee3-4399-877b-baf89c9f6f46#EUW', 'e7c3c0fd-cee3-4399-877b-baf89c9f6f46#EUW', 'capeu#009', 'RATOLOL#RAGE', 'RATOLOL#RAGE', 'Faísca amassada#BR1', 'sparck#gado', 'capeu#009', 'capeu#009', 'Âme Apaisée#EUW', 'SlayerSupreme#2003', 'Krau#Sona', 'xPπ#wuji']

# %%
def data_processing(data):
  #new cols 'division', 'rank', 'lp' full of nones
  data['division'] = np.nan
  data['rank'] = np.nan
  data['lp'] = np.nan
  
  for i in range(len(data)):
    #split rank_lp to rank, lp
    if len(data.loc[i, 'rank_lp'].split()) == 4:
      div, rank, lp, _ = data.loc[i, 'rank_lp'].split(' ')
      data.loc[i, ['division', 'rank', 'lp']] = div, rank, lp
    elif len(data.loc[i, 'rank_lp'].split()) == 3:
      div, lp, _ = data.loc[i, 'rank_lp'].split(' ')
      data.loc[i, ['division', 'rank', 'lp']] = div, None, lp
    else:
      div, rank = data.loc[i, 'rank_lp'].split(' ')
      data.loc[i, ['division', 'rank', 'lp']] = div, rank, 0
  
  romav_dict = {'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5, None: None}
  data['rank'] = data['rank'].map(romav_dict)
  
  
  
  
  #split winrate to winrate, games_played. last part is rate, second last is game_played
  data[['_', 'games_won', 'winrate']] = data['winrate'].str.split(' ', expand=True)
  #filter winrate from % and ()
  data['winrate'] = data['winrate'].str.replace('%', '').str.replace('(', '').str.replace(')', '')
  #split kda to kills, death, assists
  data[['kills', 'death', 'assists']] = data['kda'].str.split('/', expand=True)
  #drop rank_lp, kda
  data = data.drop(['rank_lp', 'kda', '_'], axis=1) # Remove '_' from the list of columns to drop.
  #show first 10 lines
  return data
# Out:
# <ipython-input-16-dd57c68858b1>:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Challenger' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, ['division', 'rank', 'lp']] = div, None, lp
# <ipython-input-16-dd57c68858b1>:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1248' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, ['division', 'rank', 'lp']] = div, None, lp
# <ipython-input-16-dd57c68858b1>:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'I' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, ['division', 'rank', 'lp']] = div, rank, lp
#                   username winrate  \
# 0                Faker#031    69.8
# 1              Sevaski#aaa    61.7
# 2            NekoDesu#1009    62.0
# 3             Inserial#SG2    58.3
# 4       Inevitabilis#Death    54.0
# ...                    ...     ...
# 4995       Smallwhite#9732    54.5
# 4996      LunarDragoon#SG2    48.0
# 4997             Dbae#4444    52.9
# 4998        BlackReWin#SG2    55.4
# 4999  Talk Sick Venom#Solo    42.4
#
#                                   most_played_champions most_played_role  \
# 0     ['Faker#031', 'Galio', 'Aatrox', 'Sylas', 'Yuu...              Mid
# 1     ['Sevaski#aaa', 'Zed', 'Hwei', 'Syndra', 'Oria...              Mid
# 2     ['NekoDesu#1009', 'Yone', 'Sylas', "Kai'Sa", '...              Mid
# 3     ['Inserial#SG2', "Kai'Sa", 'Ezreal', 'Jhin', '...         AD Carry
# 4     ['Inevitabilis#Death', 'Gwen', 'Wukong', 'Lee ...          Jungler
# ...                                                 ...              ...
# 4995  ['Smallwhite#9732', 'Graves', 'Ziggs', 'Swain'...          Jungler
# 4996  ['LunarDragoon#SG2', 'Jhin', 'Lux', 'Xerath', ...          Support
# 4997  ['Dbae#4444', 'Nocturne', 'Viego', 'Lee Sin', ...          Jungler
# 4998  ['BlackReWin#SG2', 'Swain', 'Darius', 'Varus',...              Top
# 4999  ['Talk Sick Venom#Solo', "Cho'Gath", 'Smolder'...              Top
#
#       avg_creeps_per_min  avg_gold_per_min     division  rank    lp games_won  \
# 0               6.133333        462.066667   Challenger   NaN  1248       113
# 1               7.800000        505.516667   Challenger   NaN  1009       111
# 2               7.516667        476.700000   Challenger   NaN   722        98
# 3               7.700000        480.333333   Challenger   NaN   516       105
# 4               7.033333        468.533333  GrandMaster   NaN   390       127
# ...                  ...               ...          ...   ...   ...       ...
# 4995            4.300000        490.166667      Emerald   4.0     0        36
# 4996            3.900000        380.016667      Emerald   4.0     0        36
# 4997            4.833333        501.116667      Emerald   4.0     0        36
# 4998            4.300000        415.566667      Emerald   4.0     0        36
# 4999            5.483333        397.566667      Emerald   4.0     0        36
#
#      kills death assists
# 0      7.4   4.1    10.0
# 1      8.3   5.9     7.8
# 2      8.0   4.4     8.5
# 3      7.4   4.8     7.5
# 4      7.4   5.0     8.2
# ...    ...   ...     ...
# 4995   5.7   4.6    10.6
# 4996   5.0   6.9    12.1
# 4997   6.0   5.2    10.1
# 4998   5.4   5.3     5.8
# 4999   6.2   5.8     6.2
#
# [5000 rows x 13 columns]

# %%
# #split rank_lp to rank, lp
# data[['rank', 'lp', '_']] = data['rank_lp'].str.split(' ', expand=True)
# #split winrate to winrate, games_played
# data[['winrate', 'games_played']] = data['winrate'].str.split(' ', expand=True)
# #split kda to kills, death, assists
# data[['kills', 'death', 'assists']] = data['kda'].str.split('/', expand=True)
# #drop rank_lp, kda
# data = data.drop(['rank_lp', 'kda', '_'], axis=1)
# #show first 10 lines
# data.head(10)

# %%
#export to csv
data.to_csv('/content/league_of_graphs_players_filtered.csv', index=False)
