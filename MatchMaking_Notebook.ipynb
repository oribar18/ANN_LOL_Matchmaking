# %% [markdown]
# **MATCH MAKER - ANN**

# %% [markdown]
# THIS FUNCTION I FOUND ON GITHUB, just a general guidline to give our own MMR

# %%
def calculate_mmr(player):
    # Base MMR by rank
    base_mmr = {
        'Iron': 200,
        'Bronze': 800,
        'Silver': 1000,
        'Gold': 1200,
        'Platinum': 1500,
        'Diamond': 1800,
        'Master': 2200,
        'GrandMaster': 2400,
        'Challenger': 2600
    }

    mmr = base_mmr.get(player['division'], 0)

    # Rank adjustments

    rank_bonus = {1: 160, 2: 120, 3: 80, 4: 40}
    if player['division'] == 'Iron':
        rank_bonus = {1: 400, 2: 300, 3: 200, 4: 100}
    elif player['division'] in ['Gold', 'Platinum', 'Diamond']:
        rank_bonus[1] += 40
        rank_bonus[2] += 30
        rank_bonus[3] += 20
        rank_bonus[4] += 10

    mmr += rank_bonus.get(player['rank'], 0)

    ##Handle Lp
    # if player['lp'] is not None:
    #     mmr += player['lp']

    # Winrate adjustments
    if player['win_rate'] >= 50:
        mmr += mmr * 0.2 * (player['win_rate'] * 0.01)
    else:
        mmr -= mmr * 0.2 * ((50 - player['win_rate']) * 0.01)

    return round(mmr, 2)


def calculate_kda(player):
    adj_deaths = max(1.0, player['death'])

    if player['role'] == 'Top':
        kda = ((1.2 * player['kills']) + player['assists']) / adj_deaths
    elif player['role'] == 'Jungler':
        kda = (player['kills'] + (1.5 * player['assists'])) / adj_deaths
    elif player['role'] == 'Mid':
        kda = ((1.5 * player['kills']) + player['assists']) / adj_deaths
    elif player['role'] == 'AD Carry':
        kda = ((2.0 * player['kills']) + player['assists']) / adj_deaths
    elif player['role'] == 'Support':
        kda = (player['kills'] + (2.0 * player['assists'])) / adj_deaths
    else:
        # Default formula (standard KDA calculation)
        kda = (player['kills'] + player['assists']) / adj_deaths

    return round(kda, 2)


def normalize_features(features):
    mmr_scale = 3000.0
    games_scale = 1000.0
    winrate_scale = 100.0
    kills_scale = 100.0
    deaths_scale = 100.0
    assists_scale = 100.0
    creeps_scale = 1000.0
    gold_scale = 10000.0
    kda_scale = 1000.0
    normalized_features = []
    normalized_features.append(features[0] / mmr_scale)
    if len(features) > 1:
      normalized_features.append(features[1] / winrate_scale)
      games_normalized = features[2] / games_scale
      if len(features) > 3:
        normalized_features.append(features[3] / creeps_scale)
        normalized_features.append(features[4] / gold_scale)
        if len(features) > 6:
          normalized_features.append(features[5] / kills_scale)
          normalized_features.append(features[6] / deaths_scale)
          normalized_features.append(features[7] / assists_scale)
        else:
          normalized_features.append(features[5] / kda_scale)

    normalized_features_np = np.array(normalized_features)
    return normalized_features_np

# %%
import pandas as pd

players = pd.read_csv('/content/league_of_graphs_players_200_filtered (2).csv')

# %%
from dataclasses import dataclass
from typing import List, Optional, Set, Tuple
import numpy as np
from scipy.spatial import cKDTree

@dataclass
class Player:
    id: str
    mmr: float
    win_rate: float
    games_played: int
    role: str
    division: str
    rank: Optional[int] = None
    lp: Optional[int] = None
    kills: Optional[float] = None
    death: Optional[float] = None
    assists: Optional[float] = None
    avg_creeps_per_min: Optional[float] = None
    avg_gold_per_min: Optional[float] = None
    calculated_kda: Optional[float] = None

    features: Optional[np.ndarray] = None

@dataclass
class Match:
    team1: List[Player]
    team2: List[Player]
    mmr_difference: float

class RoleQueue:
    def __init__(self, role: str):
        self.role = role
        self.players: List[Player] = []
        self.tree: Optional[cKDTree] = None
        self.features: Optional[np.ndarray] = None
        self.needs_rebuild = True

    def add_player(self, player: Player):
        """Add a player and mark tree for rebuilding."""
        self.players.append(player)
        self.needs_rebuild = True

    def remove_player(self, player: Player):
        """Remove a player and mark tree for rebuilding."""
        self.players.remove(player)
        self.needs_rebuild = True

    def rebuild_tree(self):
        """Rebuild the KD-tree with current players."""
        if not self.players or len(self.players) < 2:  # Need at least 2 players for role mirror
            self.tree = None
            self.features = None
            return

        # Create feature array for all players
        self.features = np.array([
            normalize_features(player.features) for player in self.players
        ])
        # features_transformed = np.array([
        #     self.features[:, 0] ,
        #     self.features[:, 1],
        #     self.features[:, 2]
        # ]).T
        num_features = self.features.shape[1]
        features_transformed_list = []
        for i in range(num_features):
            features_transformed_list.append(self.features[:, i])
        features_transformed = np.array(features_transformed_list).T

        self.tree = cKDTree(features_transformed)
        self.needs_rebuild = False

    def find_closest_players(self,
                           target_features: np.ndarray,
                           k: int = 5,
                           mmr_threshold: float = 300,
                           player_id: str = None) -> List[Tuple[float, Player]]:
        # This function is our ANN search
        """Find k closest players using the KD-tree."""
        if self.needs_rebuild:
            self.rebuild_tree()

        if not self.tree or len(self.players) < 2:
            return []


        # Query the tree for k * 2 neighbors (to have options after MMR filtering)
        distances, indices = self.tree.query(normalize_features(target_features), k=min(k * 2, len(self.players)))

        # Filter and return results
        results = []
        for dist, idx in zip(distances, indices):
            candidate  = self.players[idx]
            # Check if same player
            if player_id is not None and candidate.id == player_id:
                continue
            # Check MMR threshold
            if abs(candidate.mmr - target_features[0]) <= mmr_threshold:
                results.append((dist, candidate))

            if len(results) >= k:
                break

        return results

class ImprovedMatchmaker:
    def __init__(self):
        self.role_queues = {
            role: RoleQueue(role)
            for role in ["Jungler", "Support", "Mid", "Top", "AD Carry"]
        }

    def add_player(self, player: Player):
        """Add player to appropriate role queue."""
        self.role_queues[player.role].add_player(player)

    def _calculate_team_stats(self, team: List[Player]) -> dict:
      return  {
            'avg_mmr': np.mean([p.mmr for p in team]),
            'avg_wr': np.mean([p.win_rate for p in team]),
            'mmr_spread': np.std([p.mmr for p in team])
        }

    def _is_balanced_match(self, team1: List[Player], team2: List[Player],
                      max_mmr_diff: float = 100) -> bool:
        """Check if two teams are balanced."""
        team1_stats = self._calculate_team_stats(team1)
        team2_stats = self._calculate_team_stats(team2)
        mmr_difference = abs(team1_stats['avg_mmr'] - team2_stats['avg_mmr'])
        return (mmr_difference <= max_mmr_diff and
                team1_stats['mmr_spread'] < 400 and
                team2_stats['mmr_spread'] < 400)


    def find_match(self, team_size: int = 5) -> Optional[List[Player]]:
        """Find a balanced team using efficient KD-tree searches."""
        # Need at least 2 players in each role
        if any(len(self.role_queues[role].players) < 2 for role in
               ["Jungler", "Support", "Mid", "Top", "AD Carry"]):
            return None

        # Sort roles by queue length for efficiency
        sorted_roles = sorted(
            self.role_queues.keys(),
            key=lambda r: len(self.role_queues[r].players),
            reverse=True
        )

        # Try each player in the shortest queue as a starting point
        shortest_queue = self.role_queues[sorted_roles[-1]]
        for starter in shortest_queue.players:
            match = self._build_teams_from_starter(starter, sorted_roles)
            if match:
              # Remove matched players from queues
                # for player in match.team1 + match.team2:
                #     self.role_queues[player.role].remove_player(player)
                return match

        return None

    def _build_teams_from_starter(self, starter: Player, role_order: List[str]) -> Optional[List[Player]]:
        """Try to build a balanced team starting with given player."""
        team1 = [starter]
        team2 = []
        used_roles = {starter.role}
        # Adding a mirror starter for team 2
        role_queue = self.role_queues[starter.role]
        matches = role_queue.find_closest_players(
            starter.features,
            k=3,  # Get top 3 candidates
            mmr_threshold=300,
            player_id=starter.id
        )
        if matches:
            # Take the closest match
            team2.append(matches[0][1])
        else:
            return None  # Cannot complete team


        for role in role_order:
            if role in used_roles:
                continue

            # Update target features based on current team
            feature_matrix = np.array([p.features for p in team1])
            team_features1 = np.mean(feature_matrix, axis=0)
            # feature_matrix2 = np.array([p.features for p in team2])
            # team_features2 = np.mean(feature_matrix, axis=0)


            # Find closest players in this role using KD-tree
            role_queue = self.role_queues[role]
            matches = role_queue.find_closest_players(
                team_features1,
                k=3,  # Get top 3 candidates
                mmr_threshold=300
            )

            if matches:
                # Take the closest match
                new_player = matches[0][1]
                team1.append(matches[0][1])
            else:
                return None  # Cannot complete team

            #find a soothing player for team 2
            matches = role_queue.find_closest_players(
            new_player.features,
            k=3,  # Get top 3 candidates
            mmr_threshold=300,
            player_id=new_player.id
            )
            if matches:
            # Take the closest match
              team2.append(matches[0][1])
              used_roles.add(role)
            else:
              return None  # Cannot complete team

        # Verify final match balance
        if self._is_balanced_match(team1, team2):
            mmr_diff = abs(np.mean([p.mmr for p in team1]) -
                         np.mean([p.mmr for p in team2]))
            return Match(team1, team2, mmr_diff)

        return None

# %%
num_matches = 10
active_features_options = ['mmr, win_rate, games_played',
                          'mmr',
                          'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, kills, death, assists',
                          'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, calculated_kda']
def test_matchmaker(active_features_option='mmr, win_rate, games_played'):
    import time

    matchmaker = ImprovedMatchmaker()


    # Add n players
    active_payers = players.sample(n=180)
    for player in active_payers.itertuples():
        player = Player(
            id=player.username,
            mmr= None ,
            win_rate=player.winrate,
            games_played=player.games_won, #NOT PLAYED
            role=player.most_played_role,
            rank=player.rank,
            division=player.division,
            lp=player.lp,
            kills=player.kills,
            death=player.death,
            assists=player.assists,
            avg_creeps_per_min=player.avg_creeps_per_min,
            avg_gold_per_min=player.avg_gold_per_min,
            calculated_kda = None
        )
        player.mmr = calculate_mmr(player.__dict__)
        player.calculated_kda = calculate_kda(player.__dict__)
        active_features_dict = {'mmr, win_rate, games_played': [player.mmr, player.win_rate, player.games_played],
                                'mmr': [player.mmr],
                                'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, kills, death, assists': [player.mmr, player.win_rate, player.games_played, player.avg_creeps_per_min, player.avg_gold_per_min, player.kills, player.death, player.assists],
                                'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, calculated_kda': [player.mmr, player.win_rate, player.games_played, player.avg_creeps_per_min, player.avg_gold_per_min, player.calculated_kda],
                                }
        player.features = np.array(active_features_dict[active_features_option])
        # player.features = np.array([player.mmr, player.win_rate, player.games_played])
        matchmaker.add_player(player)


    # Time the matching process
    start_time = time.time()
    final_match = matchmaker.find_match()
    end_time = time.time()

    if final_match:
        print(f"Formed teams in {end_time - start_time:.3f} seconds:")
        print("Team 1:")
        for player in final_match.team1:
            print(f"Role: {player.role}, Name: {player.id}, MMR: {player.mmr:.0f}, "
                  f"WR: {player.win_rate:.3f}, Games: {player.games_played}")

        # Calculate team1 stats
        team_mmr = np.mean([p.mmr for p in final_match.team1])
        mmr_spread = np.std([p.mmr for p in final_match.team1])
        print(f"\nTeam MMR: {team_mmr:.0f} ± {mmr_spread:.0f}")
        print()

        print("Team 2:")
        for player in final_match.team2:
            print(f"Role: {player.role}, Name: {player.id}, MMR: {player.mmr:.0f}, "
                  f"WR: {player.win_rate:.3f}, Games: {player.games_played}")

        # Calculate team2 stats
        team_mmr = np.mean([p.mmr for p in final_match.team2])
        mmr_spread = np.std([p.mmr for p in final_match.team2])
        print(f"\nTeam MMR: {team_mmr:.0f} ± {mmr_spread:.0f}")

        print(f"\nMMR Difference: {final_match.mmr_difference:.0f}\n")
        print("*"*100)

        return final_match


    else:
        print("Could not find balanced teams")

matches = []
for option in active_features_options:
    print(f"Testing with {option} features:")
    for i in range(num_matches):
        matches.append(test_matchmaker(option))
    print("*"*100)
    print("*"*100)
    print("*"*100)
# Out:
# Testing with mmr, win_rate, games_played features:
# Formed teams in 0.003 seconds:
# Team 1:
# Role: Jungler, Name: chatrestricted#1269, MMR: 2662, WR: 54.600, Games: 159
# Role: AD Carry, Name: 我是LJW的爸爸#LJW, MMR: 2665, WR: 55.300, Games: 105
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
# Role: Support, Name: Dawn of us#6114, MMR: 2662, WR: 54.500, Games: 108
#
# Team MMR: 2664 ± 3
#
# Team 2:
# Role: Jungler, Name: Inevitabilis#Death, MMR: 2659, WR: 54.000, Games: 127
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: Top, Name: 他在家里显得很弱势总是窝里受气#123, MMR: 2655, WR: 53.200, Games: 91
# Role: Support, Name: jerm#zuckr, MMR: 2658, WR: 53.700, Games: 95
#
# Team MMR: 2664 ± 8
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.005 seconds:
# Team 1:
# Role: Support, Name: Baxcalibur#0997, MMR: 2192, WR: 48.200, Games: 40
# Role: AD Carry, Name: Tockie#4876, MMR: 2199, WR: 49.700, Games: 79
# Role: Mid, Name: Ken1#5678, MMR: 2198, WR: 49.500, Games: 55
# Role: Jungler, Name: 小明打野#1827, MMR: 2199, WR: 49.800, Games: 120
# Role: Top, Name: Solo#Dboy, MMR: 2196, WR: 49.000, Games: 169
#
# Team MMR: 2197 ± 3
#
# Team 2:
# Role: Support, Name: 愿神也佑妮#7enny, MMR: 2198, WR: 49.600, Games: 62
# Role: AD Carry, Name: The UnForGiv3nS#sohai, MMR: 2201, WR: 50.300, Games: 168
# Role: Mid, Name: 口合口合口合口合口合口合口合口合#哈哈哈哈哈, MMR: 2199, WR: 49.800, Games: 161
# Role: Jungler, Name: jeli#bwear, MMR: 2200, WR: 50.000, Games: 22
# Role: Top, Name: RedditExplorer#SG5, MMR: 2203, WR: 50.700, Games: 72
#
# Team MMR: 2200 ± 2
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.004 seconds:
# Team 1:
# Role: Support, Name: imwinter#180, MMR: 2207, WR: 51.800, Games: 58
# Role: AD Carry, Name: Soryu#0613, MMR: 2206, WR: 51.500, Games: 52
# Role: Mid, Name: Evaine#woof, MMR: 2208, WR: 51.900, Games: 28
# Role: Jungler, Name: MinatoAqua#8781, MMR: 2207, WR: 51.800, Games: 85
# Role: Top, Name: RedditExplorer#SG5, MMR: 2203, WR: 50.700, Games: 72
#
# Team MMR: 2206 ± 2
#
# Team 2:
# Role: Support, Name: Laze#0070, MMR: 2209, WR: 52.300, Games: 69
# Role: AD Carry, Name: ehahae#1455, MMR: 2204, WR: 50.900, Games: 117
# Role: Mid, Name: Fengwee#2500, MMR: 2205, WR: 51.200, Games: 83
# Role: Jungler, Name: 橘外人#1004, MMR: 2204, WR: 51.100, Games: 184
# Role: Top, Name: Jys#6909, MMR: 2202, WR: 50.500, Games: 56
#
# Team MMR: 2205 ± 2
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
# Role: AD Carry, Name: watermelon123#aaa, MMR: 2682, WR: 58.700, Games: 98
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: Mid, Name: 白狐狸#Fxx, MMR: 2674, WR: 57.100, Games: 64
# Role: Jungler, Name: FP Poppy#SG2, MMR: 2673, WR: 56.900, Games: 119
#
# Team MMR: 2678 ± 4
#
# Team 2:
# Role: Support, Name: WNY KiWi#0129, MMR: 2679, WR: 58.200, Games: 78
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: Jungler, Name: Joey Swift#3174, MMR: 2673, WR: 56.900, Games: 74
#
# Team MMR: 2678 ± 7
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.003 seconds:
# Team 1:
# Role: Top, Name: Solo#Dboy, MMR: 2196, WR: 49.000, Games: 169
# Role: AD Carry, Name: Tockie#4876, MMR: 2199, WR: 49.700, Games: 79
# Role: Support, Name: 愿神也佑妮#7enny, MMR: 2198, WR: 49.600, Games: 62
# Role: Mid, Name: Ken1#5678, MMR: 2198, WR: 49.500, Games: 55
# Role: Jungler, Name: 小明打野#1827, MMR: 2199, WR: 49.800, Games: 120
#
# Team MMR: 2198 ± 1
#
# Team 2:
# Role: Top, Name: Jys#6909, MMR: 2202, WR: 50.500, Games: 56
# Role: AD Carry, Name: The UnForGiv3nS#sohai, MMR: 2201, WR: 50.300, Games: 168
# Role: Support, Name: Baxcalibur#0997, MMR: 2192, WR: 48.200, Games: 40
# Role: Mid, Name: 口合口合口合口合口合口合口合口合#哈哈哈哈哈, MMR: 2199, WR: 49.800, Games: 161
# Role: Jungler, Name: jeli#bwear, MMR: 2200, WR: 50.000, Games: 22
#
# Team MMR: 2199 ± 4
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: AD Carry, Name: Worcestershire#7high, MMR: 2448, WR: 56.400, Games: 133
# Role: Jungler, Name: IVAR BONELESS#666, MMR: 2448, WR: 56.400, Games: 53
# Role: Support, Name: FudgeNugget#SG2, MMR: 2449, WR: 56.500, Games: 48
# Role: Mid, Name: 我很想你#0724, MMR: 2449, WR: 56.600, Games: 56
# Role: Top, Name: Riddim#SG2, MMR: 2448, WR: 56.400, Games: 31
#
# Team MMR: 2448 ± 0
#
# Team 2:
# Role: AD Carry, Name: Yan#13112, MMR: 2446, WR: 55.900, Games: 57
# Role: Jungler, Name: see#1112, MMR: 2448, WR: 56.300, Games: 67
# Role: Support, Name: TalkingCake#SG2, MMR: 2449, WR: 56.500, Games: 65
# Role: Mid, Name: Orca#2841, MMR: 2456, WR: 58.100, Games: 54
# Role: Top, Name: Old God Volibear#STORM, MMR: 2449, WR: 56.600, Games: 81
#
# Team MMR: 2449 ± 3
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.009 seconds:
# Team 1:
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: Jungler, Name: FP Poppy#SG2, MMR: 2673, WR: 56.900, Games: 119
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Support, Name: WNY KiWi#0129, MMR: 2679, WR: 58.200, Games: 78
#
# Team MMR: 2675 ± 3
#
# Team 2:
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: Jungler, Name: Joey Swift#3174, MMR: 2673, WR: 56.900, Games: 74
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: AD Carry, Name: watermelon123#aaa, MMR: 2682, WR: 58.700, Games: 98
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
#
# Team MMR: 2679 ± 8
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.005 seconds:
# Team 1:
# Role: Support, Name: 君子不救#komer, MMR: 2427, WR: 51.600, Games: 49
# Role: AD Carry, Name: JOHN PORK#3731, MMR: 2427, WR: 51.500, Games: 139
# Role: Top, Name: 这游戏不知道怎么玩#3333, MMR: 2425, WR: 51.200, Games: 87
# Role: Mid, Name: 第几梦#Ionia, MMR: 2424, WR: 51.000, Games: 53
# Role: Jungler, Name: 문현준#KR222, MMR: 2431, WR: 52.600, Games: 81
#
# Team MMR: 2427 ± 2
#
# Team 2:
# Role: Support, Name: Kayy#1321, MMR: 2438, WR: 54.200, Games: 77
# Role: AD Carry, Name: iSaltedFish#FISH, MMR: 2430, WR: 52.200, Games: 60
# Role: Top, Name: 橘内人#JNR, MMR: 2424, WR: 50.800, Games: 67
# Role: Mid, Name: 다포이 제너#KHY, MMR: 2422, WR: 50.400, Games: 59
# Role: Jungler, Name: beef boss#beef, MMR: 2435, WR: 53.300, Games: 57
#
# Team MMR: 2430 ± 6
#
# MMR Difference: 3
#
# ****************************************************************************************************
# Formed teams in 0.007 seconds:
# Team 1:
# Role: Support, Name: Coroo#SG2, MMR: 2211, WR: 52.700, Games: 39
# Role: AD Carry, Name: ADCSL#QUW0, MMR: 2211, WR: 52.700, Games: 166
# Role: Mid, Name: helloworld#9917, MMR: 2213, WR: 53.200, Games: 42
# Role: Jungler, Name: kelvos#086, MMR: 2214, WR: 53.500, Games: 23
# Role: Top, Name: Kaihua#SG1, MMR: 2212, WR: 53.000, Games: 44
#
# Team MMR: 2212 ± 1
#
# Team 2:
# Role: Support, Name: bloop#727, MMR: 2212, WR: 52.900, Games: 18
# Role: AD Carry, Name: BornThisWay7#SG2, MMR: 2210, WR: 52.500, Games: 21
# Role: Mid, Name: PastryLord#4153, MMR: 2217, WR: 54.300, Games: 38
# Role: Jungler, Name: Dodobird#4586, MMR: 2219, WR: 54.700, Games: 41
# Role: Top, Name: Poppy Bryan#KEKW, MMR: 2214, WR: 53.500, Games: 53
#
# Team MMR: 2214 ± 3
#
# MMR Difference: 2
#
# ****************************************************************************************************
# Formed teams in 0.006 seconds:
# Team 1:
# Role: Jungler, Name: Rachhh#0721, MMR: 2724, WR: 67.600, Games: 48
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: AD Carry, Name: Squirrel#958, MMR: 2699, WR: 62.300, Games: 48
# Role: Support, Name: DR PHIL#CRACK, MMR: 2689, WR: 60.300, Games: 41
# Role: Mid, Name: aura#drrl, MMR: 2711, WR: 64.700, Games: 110
#
# Team MMR: 2703 ± 13
#
# Team 2:
# Role: Jungler, Name: hauser#SG2, MMR: 2713, WR: 65.200, Games: 45
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: AD Carry, Name: polop#SG2, MMR: 2697, WR: 61.800, Games: 47
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
# Role: Mid, Name: Arykelic#Ary, MMR: 2713, WR: 65.300, Games: 32
#
# Team MMR: 2697 ± 15
#
# MMR Difference: 6
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Testing with mmr features:
# Formed teams in 0.010 seconds:
# Team 1:
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Jungler, Name: Joey Swift#3174, MMR: 2673, WR: 56.900, Games: 74
# Role: Support, Name: WNY KiWi#0129, MMR: 2679, WR: 58.200, Games: 78
# Role: Mid, Name: 白狐狸#Fxx, MMR: 2674, WR: 57.100, Games: 64
#
# Team MMR: 2676 ± 2
#
# Team 2:
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: AD Carry, Name: watermelon123#aaa, MMR: 2682, WR: 58.700, Games: 98
# Role: Jungler, Name: FP Poppy#SG2, MMR: 2673, WR: 56.900, Games: 119
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
#
# Team MMR: 2680 ± 7
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.004 seconds:
# Team 1:
# Role: Mid, Name: 다포이 제너#KHY, MMR: 2422, WR: 50.400, Games: 59
# Role: AD Carry, Name: Dantiz#SG9, MMR: 2420, WR: 50.000, Games: 186
# Role: Jungler, Name: 문현준#KR222, MMR: 2431, WR: 52.600, Games: 81
# Role: Top, Name: 这游戏不知道怎么玩#3333, MMR: 2425, WR: 51.200, Games: 87
# Role: Support, Name: 君子不救#komer, MMR: 2427, WR: 51.600, Games: 49
#
# Team MMR: 2425 ± 4
#
# Team 2:
# Role: Mid, Name: 第几梦#Ionia, MMR: 2424, WR: 51.000, Games: 53
# Role: AD Carry, Name: JOHN PORK#3731, MMR: 2427, WR: 51.500, Games: 139
# Role: Jungler, Name: 04 topboy#FREE, MMR: 2431, WR: 52.600, Games: 60
# Role: Top, Name: 橘内人#JNR, MMR: 2424, WR: 50.800, Games: 67
# Role: Support, Name: Kayy#1321, MMR: 2438, WR: 54.200, Games: 77
#
# Team MMR: 2429 ± 6
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.006 seconds:
# Team 1:
# Role: Support, Name: 枫落残雪#1214, MMR: 2230, WR: 57.400, Games: 27
# Role: AD Carry, Name: le heist#911, MMR: 2222, WR: 55.400, Games: 31
# Role: Jungler, Name: 秋 叶#1006, MMR: 2224, WR: 56.100, Games: 32
# Role: Top, Name: miroh#SG2, MMR: 2226, WR: 56.500, Games: 26
# Role: Mid, Name: poulet dakatine#SG2, MMR: 2230, WR: 57.400, Games: 58
#
# Team MMR: 2226 ± 3
#
# Team 2:
# Role: Support, Name: aery#Janna, MMR: 2236, WR: 58.900, Games: 56
# Role: AD Carry, Name: Greter#0714, MMR: 2215, WR: 53.800, Games: 42
# Role: Jungler, Name: Dodobird#4586, MMR: 2219, WR: 54.700, Games: 41
# Role: Top, Name: Camper#2868, MMR: 2228, WR: 56.900, Games: 62
# Role: Mid, Name: GMR ValenTiNeS#GAMER, MMR: 2236, WR: 59.100, Games: 26
#
# Team MMR: 2227 ± 9
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.004 seconds:
# Team 1:
# Role: Support, Name: Crust#7332, MMR: 2210, WR: 52.400, Games: 43
# Role: Jungler, Name: MinatoAqua#8781, MMR: 2207, WR: 51.800, Games: 85
# Role: Mid, Name: Evaine#woof, MMR: 2208, WR: 51.900, Games: 28
# Role: Top, Name: Kaihua#SG1, MMR: 2212, WR: 53.000, Games: 44
# Role: AD Carry, Name: BornThisWay7#SG2, MMR: 2210, WR: 52.500, Games: 21
#
# Team MMR: 2209 ± 2
#
# Team 2:
# Role: Support, Name: Laze#0070, MMR: 2209, WR: 52.300, Games: 69
# Role: Jungler, Name: 橘外人#1004, MMR: 2204, WR: 51.100, Games: 184
# Role: Mid, Name: Fengwee#2500, MMR: 2205, WR: 51.200, Games: 83
# Role: Top, Name: Poppy Bryan#KEKW, MMR: 2214, WR: 53.500, Games: 53
# Role: AD Carry, Name: ADCSL#QUW0, MMR: 2211, WR: 52.700, Games: 166
#
# Team MMR: 2209 ± 4
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: 嘉莉大美女#Jiali, MMR: 2773, WR: 77.800, Games: 28
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: AD Carry, Name: Squirrel#958, MMR: 2699, WR: 62.300, Games: 48
# Role: Mid, Name: Arykelic#Ary, MMR: 2713, WR: 65.300, Games: 32
# Role: Jungler, Name: Rachhh#0721, MMR: 2724, WR: 67.600, Games: 48
#
# Team MMR: 2720 ± 29
#
# Team 2:
# Role: Support, Name: DR PHIL#CRACK, MMR: 2689, WR: 60.300, Games: 41
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: AD Carry, Name: polop#SG2, MMR: 2697, WR: 61.800, Games: 47
# Role: Mid, Name: Faker#5STAR, MMR: 2687, WR: 59.800, Games: 67
# Role: Jungler, Name: hauser#SG2, MMR: 2713, WR: 65.200, Games: 45
#
# Team MMR: 2692 ± 12
#
# MMR Difference: 28
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: 枫落残雪#1214, MMR: 2230, WR: 57.400, Games: 27
# Role: Jungler, Name: catharsis#5092, MMR: 2234, WR: 58.600, Games: 51
# Role: Top, Name: BaneOfHades#Hades, MMR: 2232, WR: 57.900, Games: 22
# Role: Mid, Name: poulet dakatine#SG2, MMR: 2230, WR: 57.400, Games: 58
# Role: AD Carry, Name: QingYu#1120, MMR: 2240, WR: 60.000, Games: 21
#
# Team MMR: 2233 ± 4
#
# Team 2:
# Role: Support, Name: Soobin#ILWY, MMR: 2228, WR: 57.100, Games: 60
# Role: Jungler, Name: LyingEarsy#hsznb, MMR: 2244, WR: 61.100, Games: 22
# Role: Top, Name: Hyun SuYunjin#SG2, MMR: 2231, WR: 57.700, Games: 203
# Role: Mid, Name: PastryLord#4153, MMR: 2217, WR: 54.300, Games: 38
# Role: AD Carry, Name: NGGG#mooch, MMR: 2241, WR: 60.300, Games: 47
#
# Team MMR: 2232 ± 10
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.010 seconds:
# Team 1:
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: AD Carry, Name: WNY Wind#悠米跟我走, MMR: 2689, WR: 60.200, Games: 50
# Role: Jungler, Name: dogwifhat#5730, MMR: 2689, WR: 60.200, Games: 53
# Role: Support, Name: DR PHIL#CRACK, MMR: 2689, WR: 60.300, Games: 41
# Role: Mid, Name: Faker#5STAR, MMR: 2687, WR: 59.800, Games: 67
#
# Team MMR: 2689 ± 1
#
# Team 2:
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: AD Carry, Name: Somniphobia#SG2, MMR: 2691, WR: 60.600, Games: 97
# Role: Jungler, Name: Bugatti Ben#417, MMR: 2690, WR: 60.500, Games: 52
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
# Role: Mid, Name: 白狐狸#Fxx, MMR: 2674, WR: 57.100, Games: 64
#
# Team MMR: 2683 ± 7
#
# MMR Difference: 6
#
# ****************************************************************************************************
# Formed teams in 0.001 seconds:
# Team 1:
# Role: Support, Name: Crust#7332, MMR: 2210, WR: 52.400, Games: 43
# Role: AD Carry, Name: BornThisWay7#SG2, MMR: 2210, WR: 52.500, Games: 21
# Role: Mid, Name: Evaine#woof, MMR: 2208, WR: 51.900, Games: 28
# Role: Top, Name: Kaihua#SG1, MMR: 2212, WR: 53.000, Games: 44
# Role: Jungler, Name: kelvos#086, MMR: 2214, WR: 53.500, Games: 23
#
# Team MMR: 2211 ± 2
#
# Team 2:
# Role: Support, Name: Laze#0070, MMR: 2209, WR: 52.300, Games: 69
# Role: AD Carry, Name: ADCSL#QUW0, MMR: 2211, WR: 52.700, Games: 166
# Role: Mid, Name: Fengwee#2500, MMR: 2205, WR: 51.200, Games: 83
# Role: Top, Name: Pro Pain#SG2, MMR: 2216, WR: 54.000, Games: 34
# Role: Jungler, Name: Dodobird#4586, MMR: 2219, WR: 54.700, Games: 41
#
# Team MMR: 2212 ± 5
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.001 seconds:
# Team 1:
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: Jungler, Name: FP Poppy#SG2, MMR: 2673, WR: 56.900, Games: 119
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: Support, Name: WNY KiWi#0129, MMR: 2679, WR: 58.200, Games: 78
#
# Team MMR: 2675 ± 3
#
# Team 2:
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: Jungler, Name: Joey Swift#3174, MMR: 2673, WR: 56.900, Games: 74
# Role: AD Carry, Name: watermelon123#aaa, MMR: 2682, WR: 58.700, Games: 98
# Role: Top, Name: Gubb#6366, MMR: 2690, WR: 60.400, Games: 64
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
#
# Team MMR: 2679 ± 8
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.006 seconds:
# Team 1:
# Role: Support, Name: imwinter#180, MMR: 2207, WR: 51.800, Games: 58
# Role: AD Carry, Name: Soryu#0613, MMR: 2206, WR: 51.500, Games: 52
# Role: Jungler, Name: MinatoAqua#8781, MMR: 2207, WR: 51.800, Games: 85
# Role: Top, Name: RedditExplorer#SG5, MMR: 2203, WR: 50.700, Games: 72
# Role: Mid, Name: Fengwee#2500, MMR: 2205, WR: 51.200, Games: 83
#
# Team MMR: 2206 ± 2
#
# Team 2:
# Role: Support, Name: Laze#0070, MMR: 2209, WR: 52.300, Games: 69
# Role: AD Carry, Name: ehahae#1455, MMR: 2204, WR: 50.900, Games: 117
# Role: Jungler, Name: 橘外人#1004, MMR: 2204, WR: 51.100, Games: 184
# Role: Top, Name: Jys#6909, MMR: 2202, WR: 50.500, Games: 56
# Role: Mid, Name: Evaine#woof, MMR: 2208, WR: 51.900, Games: 28
#
# Team MMR: 2205 ± 3
#
# MMR Difference: 0
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Testing with mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, kills, death, assists features:
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: DR PHIL#CRACK, MMR: 2689, WR: 60.300, Games: 41
# Role: Jungler, Name: dogwifhat#5730, MMR: 2689, WR: 60.200, Games: 53
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: AD Carry, Name: watermelon123#aaa, MMR: 2682, WR: 58.700, Games: 98
# Role: Mid, Name: Faker#5STAR, MMR: 2687, WR: 59.800, Games: 67
#
# Team MMR: 2685 ± 5
#
# Team 2:
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
# Role: Jungler, Name: Bugatti Ben#417, MMR: 2690, WR: 60.500, Games: 52
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Mid, Name: 白狐狸#Fxx, MMR: 2674, WR: 57.100, Games: 64
#
# Team MMR: 2677 ± 10
#
# MMR Difference: 8
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: dcor#sstar, MMR: 2446, WR: 56.000, Games: 70
# Role: Top, Name: Riddim#SG2, MMR: 2448, WR: 56.400, Games: 31
# Role: AD Carry, Name: Worcestershire#7high, MMR: 2448, WR: 56.400, Games: 133
# Role: Jungler, Name: 死亡聆听#jug, MMR: 2439, WR: 54.400, Games: 147
# Role: Mid, Name: 诸葛暗#7227, MMR: 2441, WR: 54.800, Games: 34
#
# Team MMR: 2445 ± 4
#
# Team 2:
# Role: Support, Name: Mossy#Fire, MMR: 2446, WR: 55.900, Games: 38
# Role: Top, Name: C6 Fischl#7219, MMR: 2453, WR: 57.600, Games: 102
# Role: AD Carry, Name: Bluee#KR07, MMR: 2454, WR: 57.800, Games: 159
# Role: Jungler, Name: beef boss#beef, MMR: 2435, WR: 53.300, Games: 57
# Role: Mid, Name: Jung Ji Hoon#0419, MMR: 2438, WR: 54.000, Games: 75
#
# Team MMR: 2445 ± 8
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: 愿神也佑妮#7enny, MMR: 2198, WR: 49.600, Games: 62
# Role: AD Carry, Name: Tockie#4876, MMR: 2199, WR: 49.700, Games: 79
# Role: Jungler, Name: 小明打野#1827, MMR: 2199, WR: 49.800, Games: 120
# Role: Mid, Name: Fengwee#2500, MMR: 2205, WR: 51.200, Games: 83
# Role: Top, Name: RedditExplorer#SG5, MMR: 2203, WR: 50.700, Games: 72
#
# Team MMR: 2201 ± 3
#
# Team 2:
# Role: Support, Name: Baxcalibur#0997, MMR: 2192, WR: 48.200, Games: 40
# Role: AD Carry, Name: ehahae#1455, MMR: 2204, WR: 50.900, Games: 117
# Role: Jungler, Name: 油条离不开豆浆#0721, MMR: 2201, WR: 50.300, Games: 95
# Role: Mid, Name: Evaine#woof, MMR: 2208, WR: 51.900, Games: 28
# Role: Top, Name: Solo#Dboy, MMR: 2196, WR: 49.000, Games: 169
#
# Team MMR: 2200 ± 6
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.008 seconds:
# Team 1:
# Role: Support, Name: bloop#727, MMR: 2212, WR: 52.900, Games: 18
# Role: Mid, Name: Fengwee#2500, MMR: 2205, WR: 51.200, Games: 83
# Role: Jungler, Name: 小明打野#1827, MMR: 2199, WR: 49.800, Games: 120
# Role: Top, Name: RedditExplorer#SG5, MMR: 2203, WR: 50.700, Games: 72
# Role: AD Carry, Name: Greter#0714, MMR: 2215, WR: 53.800, Games: 42
#
# Team MMR: 2207 ± 6
#
# Team 2:
# Role: Support, Name: Crust#7332, MMR: 2210, WR: 52.400, Games: 43
# Role: Mid, Name: Evaine#woof, MMR: 2208, WR: 51.900, Games: 28
# Role: Jungler, Name: 油条离不开豆浆#0721, MMR: 2201, WR: 50.300, Games: 95
# Role: Top, Name: Solo#Dboy, MMR: 2196, WR: 49.000, Games: 169
# Role: AD Carry, Name: Leona ABS UwU#SUN, MMR: 2215, WR: 53.700, Games: 29
#
# Team MMR: 2206 ± 7
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: 嘉莉大美女#Jiali, MMR: 2773, WR: 77.800, Games: 28
# Role: AD Carry, Name: yes#doyou, MMR: 2530, WR: 75.000, Games: 21
# Role: Jungler, Name: Doctor Doggo#SG2, MMR: 2514, WR: 71.400, Games: 25
# Role: Mid, Name: bee#1106, MMR: 2530, WR: 75.000, Games: 36
# Role: Top, Name: rhaenyra#first, MMR: 2512, WR: 71.000, Games: 22
#
# Team MMR: 2572 ± 101
#
# Team 2:
# Role: Support, Name: DR PHIL#CRACK, MMR: 2689, WR: 60.300, Games: 41
# Role: AD Carry, Name: BornThisWay#777, MMR: 2491, WR: 66.200, Games: 49
# Role: Jungler, Name: 谁来阻止我1#1234, MMR: 2505, WR: 69.400, Games: 25
# Role: Mid, Name: zena#sg3, MMR: 2514, WR: 71.400, Games: 25
# Role: Top, Name: ffvwvlaw#SG2, MMR: 2488, WR: 65.500, Games: 72
#
# Team MMR: 2538 ± 76
#
# MMR Difference: 34
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: Nottieboy#1906, MMR: 2452, WR: 57.300, Games: 51
# Role: AD Carry, Name: Worcestershire#7high, MMR: 2448, WR: 56.400, Games: 133
# Role: Jungler, Name: 死亡聆听#jug, MMR: 2439, WR: 54.400, Games: 147
# Role: Mid, Name: 诸葛暗#7227, MMR: 2441, WR: 54.800, Games: 34
# Role: Top, Name: Riddim#SG2, MMR: 2448, WR: 56.400, Games: 31
#
# Team MMR: 2446 ± 5
#
# Team 2:
# Role: Support, Name: TalkingCake#SG2, MMR: 2449, WR: 56.500, Games: 65
# Role: AD Carry, Name: Bluee#KR07, MMR: 2454, WR: 57.800, Games: 159
# Role: Jungler, Name: beef boss#beef, MMR: 2435, WR: 53.300, Games: 57
# Role: Mid, Name: Jung Ji Hoon#0419, MMR: 2438, WR: 54.000, Games: 75
# Role: Top, Name: Old God Volibear#STORM, MMR: 2449, WR: 56.600, Games: 81
#
# Team MMR: 2445 ± 7
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: Nottieboy#1906, MMR: 2452, WR: 57.300, Games: 51
# Role: Jungler, Name: 死亡聆听#jug, MMR: 2439, WR: 54.400, Games: 147
# Role: Top, Name: Riddim#SG2, MMR: 2448, WR: 56.400, Games: 31
# Role: Mid, Name: 诸葛暗#7227, MMR: 2441, WR: 54.800, Games: 34
# Role: AD Carry, Name: Worcestershire#7high, MMR: 2448, WR: 56.400, Games: 133
#
# Team MMR: 2446 ± 5
#
# Team 2:
# Role: Support, Name: 최수빈#0512, MMR: 2448, WR: 56.300, Games: 67
# Role: Jungler, Name: beef boss#beef, MMR: 2435, WR: 53.300, Games: 57
# Role: Top, Name: Old God Volibear#STORM, MMR: 2449, WR: 56.600, Games: 81
# Role: Mid, Name: Jung Ji Hoon#0419, MMR: 2438, WR: 54.000, Games: 75
# Role: AD Carry, Name: Sukon#NUT, MMR: 2445, WR: 55.600, Games: 74
#
# Team MMR: 2443 ± 6
#
# MMR Difference: 3
#
# ****************************************************************************************************
# Formed teams in 0.003 seconds:
# Team 1:
# Role: Support, Name: Kitana#Kira, MMR: 2445, WR: 55.600, Games: 35
# Role: Top, Name: Riddim#SG2, MMR: 2448, WR: 56.400, Games: 31
# Role: AD Carry, Name: iSaltedFish#FISH, MMR: 2430, WR: 52.200, Games: 60
# Role: Mid, Name: 诸葛暗#7227, MMR: 2441, WR: 54.800, Games: 34
# Role: Jungler, Name: beef boss#beef, MMR: 2435, WR: 53.300, Games: 57
#
# Team MMR: 2440 ± 7
#
# Team 2:
# Role: Support, Name: dcor#sstar, MMR: 2446, WR: 56.000, Games: 70
# Role: Top, Name: Old God Volibear#STORM, MMR: 2449, WR: 56.600, Games: 81
# Role: AD Carry, Name: JOHN PORK#3731, MMR: 2427, WR: 51.500, Games: 139
# Role: Mid, Name: gummi#2884, MMR: 2429, WR: 52.000, Games: 117
# Role: Jungler, Name: 04 topboy#FREE, MMR: 2431, WR: 52.600, Games: 60
#
# Team MMR: 2436 ± 9
#
# MMR Difference: 3
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Top, Name: Tale#255, MMR: 2642, WR: 50.500, Games: 215
# Role: AD Carry, Name: sheep#yng, MMR: 2647, WR: 51.500, Games: 207
# Role: Jungler, Name: Inevitabilis#Death, MMR: 2659, WR: 54.000, Games: 127
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: Support, Name: jerm#zuckr, MMR: 2658, WR: 53.700, Games: 95
#
# Team MMR: 2655 ± 9
#
# Team 2:
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
# Role: AD Carry, Name: 我是LJW的爸爸#LJW, MMR: 2665, WR: 55.300, Games: 105
# Role: Jungler, Name: chatrestricted#1269, MMR: 2662, WR: 54.600, Games: 159
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: Support, Name: Yril#Yril, MMR: 2664, WR: 54.900, Games: 106
#
# Team MMR: 2664 ± 3
#
# MMR Difference: 10
#
# ****************************************************************************************************
# Formed teams in 0.007 seconds:
# Team 1:
# Role: Jungler, Name: frankenstein#888, MMR: 2435, WR: 53.300, Games: 88
# Role: AD Carry, Name: Sukon#NUT, MMR: 2445, WR: 55.600, Games: 74
# Role: Top, Name: BLG BIN#6195, MMR: 2437, WR: 53.900, Games: 110
# Role: Support, Name: Kayy#1321, MMR: 2438, WR: 54.200, Games: 77
# Role: Mid, Name: SKT Faker#zzy, MMR: 2436, WR: 53.600, Games: 60
#
# Team MMR: 2438 ± 4
#
# Team 2:
# Role: Jungler, Name: 문현준#KR222, MMR: 2431, WR: 52.600, Games: 81
# Role: AD Carry, Name: Yan#13112, MMR: 2446, WR: 55.900, Games: 57
# Role: Top, Name: PotatoTomatoKing#6244, MMR: 2435, WR: 53.300, Games: 81
# Role: Support, Name: 君子不救#komer, MMR: 2427, WR: 51.600, Games: 49
# Role: Mid, Name: CottonBug#SG2, MMR: 2436, WR: 53.700, Games: 87
#
# Team MMR: 2435 ± 6
#
# MMR Difference: 3
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Testing with mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, calculated_kda features:
# Formed teams in 0.008 seconds:
# Team 1:
# Role: Support, Name: Slyslasher#0360, MMR: 2467, WR: 60.600, Games: 63
# Role: Mid, Name: omo2#jpeg, MMR: 2475, WR: 62.500, Games: 45
# Role: AD Carry, Name: BIGMOMMA#farts, MMR: 2468, WR: 60.900, Games: 42
# Role: Top, Name: Beumchan Lee#IDN, MMR: 2468, WR: 61.000, Games: 36
# Role: Jungler, Name: Tong#SG2, MMR: 2460, WR: 59.100, Games: 75
#
# Team MMR: 2468 ± 5
#
# Team 2:
# Role: Support, Name: jetix8#SG2, MMR: 2463, WR: 59.700, Games: 37
# Role: Mid, Name: applejoy#poop, MMR: 2457, WR: 58.300, Games: 42
# Role: AD Carry, Name: Nidhoggr#σμα, MMR: 2464, WR: 60.000, Games: 30
# Role: Top, Name: NickArdnihc#Nick, MMR: 2464, WR: 60.000, Games: 57
# Role: Jungler, Name: 大魔王阿文#SG2, MMR: 2458, WR: 58.700, Games: 37
#
# Team MMR: 2461 ± 3
#
# MMR Difference: 7
#
# ****************************************************************************************************
# Formed teams in 0.007 seconds:
# Team 1:
# Role: Mid, Name: 白狐狸#Fxx, MMR: 2674, WR: 57.100, Games: 64
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Jungler, Name: Joey Swift#3174, MMR: 2673, WR: 56.900, Games: 74
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
# Role: Support, Name: WNY KiWi#0129, MMR: 2679, WR: 58.200, Games: 78
#
# Team MMR: 2676 ± 2
#
# Team 2:
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: AD Carry, Name: watermelon123#aaa, MMR: 2682, WR: 58.700, Games: 98
# Role: Jungler, Name: chatrestricted#1269, MMR: 2662, WR: 54.600, Games: 159
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
# Role: Support, Name: Limerence#1293, MMR: 2684, WR: 59.100, Games: 81
#
# Team MMR: 2671 ± 10
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: Yril#Yril, MMR: 2664, WR: 54.900, Games: 106
# Role: AD Carry, Name: 我是LJW的爸爸#LJW, MMR: 2665, WR: 55.300, Games: 105
# Role: Jungler, Name: chatrestricted#1269, MMR: 2662, WR: 54.600, Games: 159
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
#
# Team MMR: 2664 ± 3
#
# Team 2:
# Role: Support, Name: Dawn of us#6114, MMR: 2662, WR: 54.500, Games: 108
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Jungler, Name: Joey Swift#3174, MMR: 2673, WR: 56.900, Games: 74
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: Top, Name: nicetry#5171, MMR: 2676, WR: 57.500, Games: 96
#
# Team MMR: 2671 ± 5
#
# MMR Difference: 7
#
# ****************************************************************************************************
# Formed teams in 0.005 seconds:
# Team 1:
# Role: Support, Name: Yril#Yril, MMR: 2664, WR: 54.900, Games: 106
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: AD Carry, Name: 我是LJW的爸爸#LJW, MMR: 2665, WR: 55.300, Games: 105
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
# Role: Jungler, Name: chatrestricted#1269, MMR: 2662, WR: 54.600, Games: 159
#
# Team MMR: 2664 ± 3
#
# Team 2:
# Role: Support, Name: Dawn of us#6114, MMR: 2662, WR: 54.500, Games: 108
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Top, Name: 他在家里显得很弱势总是窝里受气#123, MMR: 2655, WR: 53.200, Games: 91
# Role: Jungler, Name: Inevitabilis#Death, MMR: 2659, WR: 54.000, Games: 127
#
# Team MMR: 2664 ± 7
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.002 seconds:
# Team 1:
# Role: Support, Name: Coroo#SG2, MMR: 2211, WR: 52.700, Games: 39
# Role: Jungler, Name: kelvos#086, MMR: 2214, WR: 53.500, Games: 23
# Role: Mid, Name: helloworld#9917, MMR: 2213, WR: 53.200, Games: 42
# Role: Top, Name: Poppy Bryan#KEKW, MMR: 2214, WR: 53.500, Games: 53
# Role: AD Carry, Name: Leona ABS UwU#SUN, MMR: 2215, WR: 53.700, Games: 29
#
# Team MMR: 2213 ± 1
#
# Team 2:
# Role: Support, Name: Crust#7332, MMR: 2210, WR: 52.400, Games: 43
# Role: Jungler, Name: Dodobird#4586, MMR: 2219, WR: 54.700, Games: 41
# Role: Mid, Name: PastryLord#4153, MMR: 2217, WR: 54.300, Games: 38
# Role: Top, Name: Pro Pain#SG2, MMR: 2216, WR: 54.000, Games: 34
# Role: AD Carry, Name: Greter#0714, MMR: 2215, WR: 53.800, Games: 42
#
# Team MMR: 2215 ± 3
#
# MMR Difference: 2
#
# ****************************************************************************************************
# Formed teams in 0.004 seconds:
# Team 1:
# Role: Support, Name: Dawn of us#6114, MMR: 2662, WR: 54.500, Games: 108
# Role: AD Carry, Name: 我是LJW的爸爸#LJW, MMR: 2665, WR: 55.300, Games: 105
# Role: Mid, Name: 瞬間即是永恆#37a1, MMR: 2668, WR: 55.800, Games: 82
# Role: Jungler, Name: chatrestricted#1269, MMR: 2662, WR: 54.600, Games: 159
# Role: Top, Name: 웨이빈03#Moo, MMR: 2661, WR: 54.300, Games: 119
#
# Team MMR: 2664 ± 3
#
# Team 2:
# Role: Support, Name: Yril#Yril, MMR: 2664, WR: 54.900, Games: 106
# Role: AD Carry, Name: 윤가이#1557, MMR: 2676, WR: 57.400, Games: 70
# Role: Mid, Name: eunae#daph, MMR: 2670, WR: 56.300, Games: 63
# Role: Jungler, Name: Inevitabilis#Death, MMR: 2659, WR: 54.000, Games: 127
# Role: Top, Name: 他在家里显得很弱势总是窝里受气#123, MMR: 2655, WR: 53.200, Games: 91
#
# Team MMR: 2665 ± 7
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.005 seconds:
# Team 1:
# Role: Support, Name: Kusuo#1725, MMR: 2455, WR: 57.900, Games: 33
# Role: Jungler, Name: Tong#SG2, MMR: 2460, WR: 59.100, Games: 75
# Role: AD Carry, Name: ice lemon tea#0801, MMR: 2455, WR: 57.900, Games: 22
# Role: Mid, Name: applejoy#poop, MMR: 2457, WR: 58.300, Games: 42
# Role: Top, Name: C6 Fischl#7219, MMR: 2453, WR: 57.600, Games: 102
#
# Team MMR: 2456 ± 2
#
# Team 2:
# Role: Support, Name: 4700 HP#SG2, MMR: 2457, WR: 58.300, Games: 28
# Role: Jungler, Name: IVAR BONELESS#666, MMR: 2448, WR: 56.400, Games: 53
# Role: AD Carry, Name: Bluee#KR07, MMR: 2454, WR: 57.800, Games: 159
# Role: Mid, Name: Orca#2841, MMR: 2456, WR: 58.100, Games: 54
# Role: Top, Name: Old God Volibear#STORM, MMR: 2449, WR: 56.600, Games: 81
#
# Team MMR: 2453 ± 3
#
# MMR Difference: 3
#
# ****************************************************************************************************
# Formed teams in 0.003 seconds:
# Team 1:
# Role: Top, Name: solipsist#SG3, MMR: 2224, WR: 56.000, Games: 51
# Role: AD Carry, Name: le heist#911, MMR: 2222, WR: 55.400, Games: 31
# Role: Jungler, Name: Dodobird#4586, MMR: 2219, WR: 54.700, Games: 41
# Role: Mid, Name: PastryLord#4153, MMR: 2217, WR: 54.300, Games: 38
# Role: Support, Name: BigWard#3693, MMR: 2222, WR: 55.600, Games: 174
#
# Team MMR: 2221 ± 2
#
# Team 2:
# Role: Top, Name: DIAMOND DAIGO#5555, MMR: 2223, WR: 55.700, Games: 131
# Role: AD Carry, Name: Greter#0714, MMR: 2215, WR: 53.800, Games: 42
# Role: Jungler, Name: kelvos#086, MMR: 2214, WR: 53.500, Games: 23
# Role: Mid, Name: helloworld#9917, MMR: 2213, WR: 53.200, Games: 42
# Role: Support, Name: Soobin#ILWY, MMR: 2228, WR: 57.100, Games: 60
#
# Team MMR: 2219 ± 6
#
# MMR Difference: 2
#
# ****************************************************************************************************
# Formed teams in 0.008 seconds:
# Team 1:
# Role: Support, Name: 愿神也佑妮#7enny, MMR: 2198, WR: 49.600, Games: 62
# Role: Jungler, Name: 小明打野#1827, MMR: 2199, WR: 49.800, Games: 120
# Role: AD Carry, Name: Tockie#4876, MMR: 2199, WR: 49.700, Games: 79
# Role: Mid, Name: 口合口合口合口合口合口合口合口合#哈哈哈哈哈, MMR: 2199, WR: 49.800, Games: 161
# Role: Top, Name: Solo#Dboy, MMR: 2196, WR: 49.000, Games: 169
#
# Team MMR: 2198 ± 1
#
# Team 2:
# Role: Support, Name: imwinter#180, MMR: 2207, WR: 51.800, Games: 58
# Role: Jungler, Name: 油条离不开豆浆#0721, MMR: 2201, WR: 50.300, Games: 95
# Role: AD Carry, Name: iiiiqqq#1234, MMR: 2202, WR: 50.400, Games: 119
# Role: Mid, Name: Ken1#5678, MMR: 2198, WR: 49.500, Games: 55
# Role: Top, Name: RedditExplorer#SG5, MMR: 2203, WR: 50.700, Games: 72
#
# Team MMR: 2202 ± 3
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.005 seconds:
# Team 1:
# Role: Support, Name: Kayy#1321, MMR: 2438, WR: 54.200, Games: 77
# Role: AD Carry, Name: Percher#SG2, MMR: 2439, WR: 54.300, Games: 25
# Role: Jungler, Name: 死亡聆听#jug, MMR: 2439, WR: 54.400, Games: 147
# Role: Mid, Name: Jung Ji Hoon#0419, MMR: 2438, WR: 54.000, Games: 75
# Role: Top, Name: BLG BIN#6195, MMR: 2437, WR: 53.900, Games: 110
#
# Team MMR: 2438 ± 1
#
# Team 2:
# Role: Support, Name: corgi cat#corgi, MMR: 2438, WR: 54.200, Games: 32
# Role: AD Carry, Name: Sukon#NUT, MMR: 2445, WR: 55.600, Games: 74
# Role: Jungler, Name: lihlo#schly, MMR: 2440, WR: 54.500, Games: 42
# Role: Mid, Name: CottonBug#SG2, MMR: 2436, WR: 53.700, Games: 87
# Role: Top, Name: PotatoTomatoKing#6244, MMR: 2435, WR: 53.300, Games: 81
#
# Team MMR: 2439 ± 3
#
# MMR Difference: 0
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
