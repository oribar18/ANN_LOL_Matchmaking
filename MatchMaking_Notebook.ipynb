# %% [markdown]
# **MATCH MAKER - ANN**

# %% [markdown]
# THIS FUNCTION I FOUND ON GITHUB, just a general guidline to give our own MMR

# %%
def calculate_mmr(player):
    # Base MMR by rank
    base_mmr = {
        'Iron': 200,
        'Bronze': 800,
        'Silver': 1000,
        'Gold': 1200,
        'Platinum': 1500,
        'Diamond': 1800,
        'Master': 2200,
        'GrandMaster': 2400,
        'Challenger': 2600
    }

    mmr = base_mmr.get(player['division'], 0)

    # Rank adjustments

    rank_bonus = {1: 160, 2: 120, 3: 80, 4: 40}
    if player['division'] == 'Iron':
        rank_bonus = {1: 400, 2: 300, 3: 200, 4: 100}
    elif player['division'] in ['Gold', 'Platinum', 'Diamond']:
        rank_bonus[1] += 40
        rank_bonus[2] += 30
        rank_bonus[3] += 20
        rank_bonus[4] += 10

    mmr += rank_bonus.get(player['rank'], 0)

    ##Handle Lp
    # if player['lp'] is not None:
    #     mmr += player['lp']

    # Winrate adjustments
    if player['win_rate'] >= 50:
        mmr += mmr * 0.2 * (player['win_rate'] * 0.01)
    else:
        mmr -= mmr * 0.2 * ((50 - player['win_rate']) * 0.01)

    return round(mmr, 2)


def calculate_kda(player):
    adj_deaths = max(1.0, player['death'])

    if player['role'] == 'Top':
        kda = ((1.2 * player['kills']) + player['assists']) / adj_deaths
    elif player['role'] == 'Jungler':
        kda = (player['kills'] + (1.5 * player['assists'])) / adj_deaths
    elif player['role'] == 'Mid':
        kda = ((1.5 * player['kills']) + player['assists']) / adj_deaths
    elif player['role'] == 'AD Carry':
        kda = ((2.0 * player['kills']) + player['assists']) / adj_deaths
    elif player['role'] == 'Support':
        kda = (player['kills'] + (2.0 * player['assists'])) / adj_deaths
    else:
        # Default formula (standard KDA calculation)
        kda = (player['kills'] + player['assists']) / adj_deaths

    return round(kda, 2)


def normalize_features(features):
    mmr_scale = 3000.0
    games_scale = 1000.0
    winrate_scale = 100.0
    kills_scale = 100.0
    deaths_scale = 100.0
    assists_scale = 100.0
    creeps_scale = 1000.0
    gold_scale = 10000.0
    kda_scale = 1000.0
    normalized_features = []
    normalized_features.append(features[0] / mmr_scale)
    if len(features) > 1:
      normalized_features.append(features[1] / winrate_scale)
      games_normalized = features[2] / games_scale
      if len(features) > 3:
        normalized_features.append(features[3] / creeps_scale)
        normalized_features.append(features[4] / gold_scale)
        if len(features) > 6:
          normalized_features.append(features[5] / kills_scale)
          normalized_features.append(features[6] / deaths_scale)
          normalized_features.append(features[7] / assists_scale)
        else:
          normalized_features.append(features[5] / kda_scale)

    normalized_features_np = np.array(normalized_features)
    return normalized_features_np

# %%
import pandas as pd

players = pd.read_csv('league_of_graphs_players_filtered.csv')

# %%
from dataclasses import dataclass
from typing import List, Optional, Set, Tuple
import numpy as np
from scipy.spatial import cKDTree

@dataclass
class Player:
    id: str
    mmr: float
    win_rate: float
    games_played: int
    role: str
    division: str
    rank: Optional[int] = None
    lp: Optional[int] = None
    kills: Optional[float] = None
    death: Optional[float] = None
    assists: Optional[float] = None
    avg_creeps_per_min: Optional[float] = None
    avg_gold_per_min: Optional[float] = None
    calculated_kda: Optional[float] = None

    features: Optional[np.ndarray] = None

@dataclass
class Match:
    team1: List[Player]
    team2: List[Player]
    mmr_difference: float

class RoleQueue:
    def __init__(self, role: str):
        self.role = role
        self.players: List[Player] = []
        self.tree: Optional[cKDTree] = None
        self.features: Optional[np.ndarray] = None
        self.needs_rebuild = True

    def add_player(self, player: Player):
        """Add a player and mark tree for rebuilding."""
        self.players.append(player)
        self.needs_rebuild = True

    def remove_player(self, player: Player):
        """Remove a player and mark tree for rebuilding."""
        self.players.remove(player)
        self.needs_rebuild = True

    def rebuild_tree(self):
        """Rebuild the KD-tree with current players."""
        if not self.players or len(self.players) < 2:  # Need at least 2 players for role mirror
            self.tree = None
            self.features = None
            return

        # Create feature array for all players
        self.features = np.array([
            normalize_features(player.features) for player in self.players
        ])
        # features_transformed = np.array([
        #     self.features[:, 0] ,
        #     self.features[:, 1],
        #     self.features[:, 2]
        # ]).T
        num_features = self.features.shape[1]
        features_transformed_list = []
        for i in range(num_features):
            features_transformed_list.append(self.features[:, i])
        features_transformed = np.array(features_transformed_list).T

        self.tree = cKDTree(features_transformed)
        self.needs_rebuild = False

    def find_closest_players(self,
                           target_features: np.ndarray,
                           k: int = 5,
                           mmr_threshold: float = 300,
                           player_id: str = None) -> List[Tuple[float, Player]]:
        # This function is our ANN search
        """Find k closest players using the KD-tree."""
        if self.needs_rebuild:
            self.rebuild_tree()

        if not self.tree or len(self.players) < 2:
            return []


        # Query the tree for k * 2 neighbors (to have options after MMR filtering)
        distances, indices = self.tree.query(normalize_features(target_features), k=min(k * 2, len(self.players)))

        # Filter and return results
        results = []
        for dist, idx in zip(distances, indices):
            candidate  = self.players[idx]
            # Check if same player
            if player_id is not None and candidate.id == player_id:
                continue
            # Check MMR threshold
            if abs(candidate.mmr - target_features[0]) <= mmr_threshold:
                results.append((dist, candidate))

            if len(results) >= k:
                break

        return results

class ImprovedMatchmaker:
    def __init__(self):
        self.role_queues = {
            role: RoleQueue(role)
            for role in ["Jungler", "Support", "Mid", "Top", "AD Carry"]
        }

    def add_player(self, player: Player):
        """Add player to appropriate role queue."""
        self.role_queues[player.role].add_player(player)

    def _calculate_team_stats(self, team: List[Player]) -> dict:
      return  {
            'avg_mmr': np.mean([p.mmr for p in team]),
            'avg_wr': np.mean([p.win_rate for p in team]),
            'mmr_spread': np.std([p.mmr for p in team])
        }

    def _is_balanced_match(self, team1: List[Player], team2: List[Player],
                      max_mmr_diff: float = 100) -> bool:
        """Check if two teams are balanced."""
        team1_stats = self._calculate_team_stats(team1)
        team2_stats = self._calculate_team_stats(team2)
        mmr_difference = abs(team1_stats['avg_mmr'] - team2_stats['avg_mmr'])
        return (mmr_difference <= max_mmr_diff and
                team1_stats['mmr_spread'] < 400 and
                team2_stats['mmr_spread'] < 400)


    def find_match(self, team_size: int = 5) -> Optional[List[Player]]:
        """Find a balanced team using efficient KD-tree searches."""
        # Need at least 2 players in each role
        if any(len(self.role_queues[role].players) < 2 for role in
               ["Jungler", "Support", "Mid", "Top", "AD Carry"]):
            return None

        # Sort roles by queue length for efficiency
        sorted_roles = sorted(
            self.role_queues.keys(),
            key=lambda r: len(self.role_queues[r].players),
            reverse=True
        )

        # Try each player in the shortest queue as a starting point
        shortest_queue = self.role_queues[sorted_roles[-1]]
        for starter in shortest_queue.players:
            match = self._build_teams_from_starter(starter, sorted_roles)
            if match:
              # Remove matched players from queues
                # for player in match.team1 + match.team2:
                #     self.role_queues[player.role].remove_player(player)
                return match

        return None

    def _build_teams_from_starter(self, starter: Player, role_order: List[str]) -> Optional[List[Player]]:
        """Try to build a balanced team starting with given player."""
        team1 = [starter]
        team2 = []
        used_roles = {starter.role}
        # Adding a mirror starter for team 2
        role_queue = self.role_queues[starter.role]
        matches = role_queue.find_closest_players(
            starter.features,
            k=3,  # Get top 3 candidates
            mmr_threshold=300,
            player_id=starter.id
        )
        if matches:
            # Take the closest match
            team2.append(matches[0][1])
        else:
            return None  # Cannot complete team


        for role in role_order:
            if role in used_roles:
                continue

            # Update target features based on current team
            feature_matrix = np.array([p.features for p in team1])
            team_features1 = np.mean(feature_matrix, axis=0)
            # feature_matrix2 = np.array([p.features for p in team2])
            # team_features2 = np.mean(feature_matrix, axis=0)


            # Find closest players in this role using KD-tree
            role_queue = self.role_queues[role]
            matches = role_queue.find_closest_players(
                team_features1,
                k=3,  # Get top 3 candidates
                mmr_threshold=300
            )

            if matches:
                # Take the closest match
                new_player = matches[0][1]
                team1.append(matches[0][1])
            else:
                return None  # Cannot complete team

            #find a soothing player for team 2
            matches = role_queue.find_closest_players(
            new_player.features,
            k=3,  # Get top 3 candidates
            mmr_threshold=300,
            player_id=new_player.id
            )
            if matches:
            # Take the closest match
              team2.append(matches[0][1])
              used_roles.add(role)
            else:
              return None  # Cannot complete team

        # Verify final match balance
        if self._is_balanced_match(team1, team2):
            mmr_diff = abs(np.mean([p.mmr for p in team1]) -
                         np.mean([p.mmr for p in team2]))
            return Match(team1, team2, mmr_diff)

        return None

# %%
num_matches = 10
active_features_options = ['mmr, win_rate, games_played',
                          'mmr',
                          'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, kills, death, assists',
                          'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, calculated_kda']
def test_matchmaker(active_features_option='mmr, win_rate, games_played'):
    import time

    matchmaker = ImprovedMatchmaker()


    # Add n players
    active_payers = players.sample(n=180)
    for player in active_payers.itertuples():
        player = Player(
            id=player.username,
            mmr= None ,
            win_rate=player.winrate,
            games_played=player.games_won, #NOT PLAYED
            role=player.most_played_role,
            rank=player.rank,
            division=player.division,
            lp=player.lp,
            kills=player.kills,
            death=player.death,
            assists=player.assists,
            avg_creeps_per_min=player.avg_creeps_per_min,
            avg_gold_per_min=player.avg_gold_per_min,
            calculated_kda = None
        )
        player.mmr = calculate_mmr(player.__dict__)
        player.calculated_kda = calculate_kda(player.__dict__)
        active_features_dict = {'mmr, win_rate, games_played': [player.mmr, player.win_rate, player.games_played],
                                'mmr': [player.mmr],
                                'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, kills, death, assists': [player.mmr, player.win_rate, player.games_played, player.avg_creeps_per_min, player.avg_gold_per_min, player.kills, player.death, player.assists],
                                'mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, calculated_kda': [player.mmr, player.win_rate, player.games_played, player.avg_creeps_per_min, player.avg_gold_per_min, player.calculated_kda],
                                }
        player.features = np.array(active_features_dict[active_features_option])
        # player.features = np.array([player.mmr, player.win_rate, player.games_played])
        matchmaker.add_player(player)


    # Time the matching process
    start_time = time.time()
    final_match = matchmaker.find_match()
    end_time = time.time()

    if final_match:
        print(f"Formed teams in {end_time - start_time:.3f} seconds:")
        print("Team 1:")
        for player in final_match.team1:
            print(f"Role: {player.role}, Name: {player.id}, MMR: {player.mmr:.0f}, "
                  f"WR: {player.win_rate:.3f}, Games: {player.games_played}")

        # Calculate team1 stats
        team_mmr = np.mean([p.mmr for p in final_match.team1])
        mmr_spread = np.std([p.mmr for p in final_match.team1])
        print(f"\nTeam MMR: {team_mmr:.0f} ± {mmr_spread:.0f}")
        print()

        print("Team 2:")
        for player in final_match.team2:
            print(f"Role: {player.role}, Name: {player.id}, MMR: {player.mmr:.0f}, "
                  f"WR: {player.win_rate:.3f}, Games: {player.games_played}")

        # Calculate team2 stats
        team_mmr = np.mean([p.mmr for p in final_match.team2])
        mmr_spread = np.std([p.mmr for p in final_match.team2])
        print(f"\nTeam MMR: {team_mmr:.0f} ± {mmr_spread:.0f}")

        print(f"\nMMR Difference: {final_match.mmr_difference:.0f}\n")
        print("*"*100)

        return final_match


    else:
        print("Could not find balanced teams")

matches = []
for option in active_features_options:
    print(f"Testing with {option} features:")
    for i in range(num_matches):
        matches.append(test_matchmaker(option))
    print("*"*100)
    print("*"*100)
    print("*"*100)
# Out:
# Testing with mmr, win_rate, games_played features:
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: MatSQH#3359, MMR: 178, WR: 54.700, Games: 94
# Role: Mid, Name: Season#2867, MMR: 178, WR: 56.100, Games: 46
# Role: Top, Name: choujay123qq#4541, MMR: 178, WR: 57.600, Games: 49
# Role: Jungler, Name: DePINs#1107, MMR: 134, WR: 57.100, Games: 8
# Role: AD Carry, Name: Bob bob#sWag, MMR: 133, WR: 55.600, Games: 15
#
# Team MMR: 160 ± 22
#
# Team 2:
# Role: Support, Name: Dear Daniel#SG2, MMR: 133, WR: 55.600, Games: 10
# Role: Mid, Name: CurryTeacher#SG2, MMR: 133, WR: 55.300, Games: 26
# Role: Top, Name: khangjoy#1234, MMR: 179, WR: 58.800, Games: 30
# Role: Jungler, Name: Varaan#SG2, MMR: 179, WR: 58.300, Games: 21
# Role: AD Carry, Name: Hide on Samira#SG2, MMR: 89, WR: 55.500, Games: 101
#
# Team MMR: 143 ± 34
#
# MMR Difference: 18
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: mymango#mango, MMR: 39, WR: 40.000, Games: 4
# Role: AD Carry, Name: FutureBanner#8192, MMR: 39, WR: 41.100, Games: 23
# Role: Jungler, Name: Spartacus#SG2, MMR: 78, WR: 38.900, Games: 7
# Role: Top, Name: Remzi#SG4, MMR: 39, WR: 41.900, Games: 26
# Role: Mid, Name: RWkXoGPH#9530, MMR: 39, WR: 40.000, Games: 4
#
# Team MMR: 47 ± 16
#
# Team 2:
# Role: Support, Name: tortugaoscura#SG2, MMR: 39, WR: 40.000, Games: 2
# Role: AD Carry, Name: luvsic#sigh, MMR: 79, WR: 42.900, Games: 6
# Role: Jungler, Name: AthenaGrote#SG2, MMR: 78, WR: 37.500, Games: 3
# Role: Top, Name: happygoluckyleh#3290, MMR: 117, WR: 38.800, Games: 54
# Role: Mid, Name: False Prophet#SG2, MMR: 78, WR: 39.300, Games: 11
#
# Team MMR: 78 ± 25
#
# MMR Difference: 31
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Top, Name: Gifts#7653, MMR: 40, WR: 48.300, Games: 73
# Role: AD Carry, Name: bBob21#5487, MMR: 80, WR: 48.500, Games: 50
# Role: Jungler, Name: Grief#5519, MMR: 40, WR: 49.400, Games: 154
# Role: Support, Name: Aza#SG3, MMR: 80, WR: 49.200, Games: 32
# Role: Mid, Name: Eridori#0000, MMR: 40, WR: 48.800, Games: 61
#
# Team MMR: 56 ± 20
#
# Team 2:
# Role: Top, Name: cmonCUH#9100, MMR: 40, WR: 48.400, Games: 15
# Role: AD Carry, Name: DreamR#MMF, MMR: 80, WR: 47.700, Games: 21
# Role: Jungler, Name: 8408#6755, MMR: 44, WR: 50.000, Games: 3
# Role: Support, Name: 温柔甜#NANA, MMR: 44, WR: 50.600, Games: 91
# Role: Mid, Name: Zarchonn#SG2, MMR: 44, WR: 50.000, Games: 7
#
# Team MMR: 50 ± 15
#
# MMR Difference: 6
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Mid, Name: lIlIlIlIlIlIlI#SG2, MMR: 44, WR: 50.000, Games: 55
# Role: Top, Name: kenoi#SUSSY, MMR: 44, WR: 50.000, Games: 21
# Role: Jungler, Name: Lendmark#123, MMR: 44, WR: 51.300, Games: 240
# Role: AD Carry, Name: Irelia#1229, MMR: 44, WR: 50.200, Games: 120
# Role: Support, Name: MrRich123123#5213, MMR: 44, WR: 50.000, Games: 7
#
# Team MMR: 44 ± 0
#
# Team 2:
# Role: Mid, Name: FlareS#ZOFGK, MMR: 44, WR: 50.000, Games: 3
# Role: Top, Name: Nikami#5774, MMR: 80, WR: 49.500, Games: 46
# Role: Jungler, Name: PRX Pearly Tan#India, MMR: 44, WR: 52.100, Games: 61
# Role: AD Carry, Name: Immortal King#4477, MMR: 44, WR: 50.000, Games: 54
# Role: Support, Name: Ánh Nắng Của Anh#keri, MMR: 44, WR: 50.900, Games: 81
#
# Team MMR: 51 ± 14
#
# MMR Difference: 7
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Evil Bard#bard, MMR: 2062, WR: 57.400, Games: 35
# Role: AD Carry, Name: Cloud2#0304, MMR: 2048, WR: 53.600, Games: 37
# Role: Jungler, Name: TheFrozen0ne#SG2, MMR: 2070, WR: 59.500, Games: 22
# Role: Top, Name: THE FINAL BOSS#lvl30, MMR: 2116, WR: 56.900, Games: 70
# Role: Mid, Name: 180cm 68kg 22cm#7908, MMR: 2114, WR: 56.300, Games: 63
#
# Team MMR: 2082 ± 28
#
# Team 2:
# Role: Support, Name: Lunaris#chim2, MMR: 2059, WR: 56.500, Games: 13
# Role: AD Carry, Name: I like Kittens#Woof, MMR: 2040, WR: 51.400, Games: 56
# Role: Jungler, Name: BoltstrikeZ#BoltZ, MMR: 2138, WR: 62.500, Games: 5
# Role: Top, Name: QQPR20#SG2, MMR: 2247, WR: 61.700, Games: 37
# Role: Mid, Name: Shinobu Kocho#9424, MMR: 2053, WR: 54.800, Games: 51
#
# Team MMR: 2107 ± 78
#
# MMR Difference: 25
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: BunBunBun#3523, MMR: 40, WR: 45.000, Games: 18
# Role: Mid, Name: purghaps#7580, MMR: 79, WR: 44.700, Games: 17
# Role: Top, Name: StainedGlass#SiO2, MMR: 79, WR: 46.200, Games: 6
# Role: Support, Name: Phoen1X#Yuumi, MMR: 79, WR: 46.400, Games: 32
# Role: AD Carry, Name: reminiscent#zzzzz, MMR: 119, WR: 45.000, Games: 9
#
# Team MMR: 79 ± 25
#
# Team 2:
# Role: Jungler, Name: MrRhodium#SG2, MMR: 40, WR: 44.400, Games: 20
# Role: Mid, Name: 미드킹#BDE, MMR: 79, WR: 44.600, Games: 29
# Role: Top, Name: pokebarry34#ABG, MMR: 119, WR: 44.400, Games: 4
# Role: Support, Name: Lord69#SG2, MMR: 119, WR: 45.500, Games: 15
# Role: AD Carry, Name: Nody Cika#SG2, MMR: 158, WR: 42.900, Games: 6
#
# Team MMR: 103 ± 40
#
# MMR Difference: 24
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Is A Cat#3680, MMR: 88, WR: 50.000, Games: 10
# Role: AD Carry, Name: 队友德玛斯了#1234, MMR: 80, WR: 49.000, Games: 74
# Role: Mid, Name: drakes beard#diddy, MMR: 44, WR: 50.000, Games: 18
# Role: Top, Name: squaggy#8116, MMR: 88, WR: 50.000, Games: 10
# Role: Jungler, Name: dawning#1010, MMR: 88, WR: 50.000, Games: 28
#
# Team MMR: 78 ± 17
#
# Team 2:
# Role: Support, Name: roof korean#pve, MMR: 88, WR: 50.000, Games: 3
# Role: AD Carry, Name: YKSgfpmc#2964, MMR: 44, WR: 50.600, Games: 40
# Role: Mid, Name: 柑橘乌云#SG2, MMR: 44, WR: 50.000, Games: 47
# Role: Top, Name: Flareon#Lit, MMR: 80, WR: 48.500, Games: 49
# Role: Jungler, Name: Will1#1234, MMR: 88, WR: 50.700, Games: 71
#
# Team MMR: 69 ± 20
#
# MMR Difference: 9
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: LastOneStanding#9063, MMR: 44, WR: 50.000, Games: 8
# Role: Jungler, Name: ink#well, MMR: 88, WR: 50.000, Games: 49
# Role: Top, Name: Flippingbirds#SGD, MMR: 44, WR: 50.000, Games: 79
# Role: Support, Name: ShadowStar#woozi, MMR: 40, WR: 48.800, Games: 20
# Role: Mid, Name: Zarchonn#SG2, MMR: 44, WR: 50.000, Games: 7
#
# Team MMR: 52 ± 18
#
# Team 2:
# Role: AD Carry, Name: WeebSlayerSan#SG2, MMR: 44, WR: 50.000, Games: 14
# Role: Jungler, Name: SPEO#1742, MMR: 120, WR: 49.000, Games: 95
# Role: Top, Name: Joi A#King, MMR: 44, WR: 51.000, Games: 26
# Role: Support, Name: SKT1MEGA2#SKT, MMR: 40, WR: 47.500, Games: 75
# Role: Mid, Name: smollchungus#8893, MMR: 44, WR: 50.000, Games: 14
#
# Team MMR: 58 ± 31
#
# MMR Difference: 6
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: Asline#love, MMR: 45, WR: 58.300, Games: 7
# Role: Top, Name: billybob619#ohio, MMR: 45, WR: 56.600, Games: 73
# Role: Support, Name: TATAKAW#Eren, MMR: 89, WR: 57.700, Games: 45
# Role: AD Carry, Name: Toppoki0311#SG2, MMR: 45, WR: 57.900, Games: 33
# Role: Mid, Name: truckun#2022, MMR: 45, WR: 58.500, Games: 120
#
# Team MMR: 54 ± 18
#
# Team 2:
# Role: Jungler, Name: Rochor MRT#1234, MMR: 45, WR: 60.000, Games: 6
# Role: Top, Name: bicho#2004, MMR: 44, WR: 56.300, Games: 9
# Role: Support, Name: MalaSuerte#9809, MMR: 89, WR: 58.500, Games: 114
# Role: AD Carry, Name: Intergrated#Lost, MMR: 45, WR: 58.100, Games: 18
# Role: Mid, Name: Peaaach#tao, MMR: 45, WR: 58.800, Games: 50
#
# Team MMR: 54 ± 18
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Purranyoid#Nyaaa, MMR: 2111, WR: 70.600, Games: 12
# Role: Top, Name: Twilight Boy#SG2, MMR: 2134, WR: 61.500, Games: 8
# Role: AD Carry, Name: JIGGLERS#1412, MMR: 2075, WR: 60.700, Games: 105
# Role: Mid, Name: Miraka#NPC, MMR: 2089, WR: 64.700, Games: 11
# Role: Jungler, Name: Hwayon#6011, MMR: 2132, WR: 61.100, Games: 11
#
# Team MMR: 2108 ± 23
#
# Team 2:
# Role: Support, Name: QQsaberQQ#SG2, MMR: 2119, WR: 57.700, Games: 75
# Role: Top, Name: T1 Dwah#9981, MMR: 2177, WR: 58.300, Games: 7
# Role: AD Carry, Name: MSG byuli#0830, MMR: 2061, WR: 56.900, Games: 41
# Role: Mid, Name: lcfiery#3758, MMR: 2069, WR: 59.100, Games: 26
# Role: Jungler, Name: FastandAccurate#00000, MMR: 2231, WR: 57.800, Games: 63
#
# Team MMR: 2131 ± 65
#
# MMR Difference: 23
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Testing with mmr features:
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Black Thief#IND, MMR: 160, WR: 49.200, Games: 60
# Role: Mid, Name: Darl#7330, MMR: 157, WR: 40.300, Games: 31
# Role: AD Carry, Name: SnowMix#SG2, MMR: 159, WR: 48.300, Games: 29
# Role: Top, Name: PIU PIU PIU#2907, MMR: 159, WR: 46.800, Games: 22
# Role: Jungler, Name: Moistur3#SG2, MMR: 149, WR: 14.300, Games: 1
#
# Team MMR: 157 ± 4
#
# Team 2:
# Role: Support, Name: Iñspírę#SG2, MMR: 156, WR: 36.200, Games: 17
# Role: Mid, Name: Kriss#hehe, MMR: 157, WR: 40.000, Games: 2
# Role: AD Carry, Name: BotlaneTerrorÏst#MRU, MMR: 177, WR: 52.600, Games: 82
# Role: Top, Name: KillERChAi#Devil, MMR: 177, WR: 51.700, Games: 30
# Role: Jungler, Name: Yoimiya#夏祭焰火, MMR: 138, WR: 73.300, Games: 33
#
# Team MMR: 161 ± 15
#
# MMR Difference: 4
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Top, Name: Herlock Sholmes#睡懒觉, MMR: 78, WR: 36.400, Games: 4
# Role: AD Carry, Name: YZD2#9290, MMR: 78, WR: 38.900, Games: 7
# Role: Support, Name: Is A Cat#3680, MMR: 88, WR: 50.000, Games: 10
# Role: Mid, Name: DanLarceny#Ren, MMR: 80, WR: 48.400, Games: 59
# Role: Jungler, Name: IM YuNaBi#0914, MMR: 80, WR: 49.100, Games: 79
#
# Team MMR: 81 ± 4
#
# Team 2:
# Role: Top, Name: Obama2#8502, MMR: 77, WR: 33.300, Games: 3
# Role: AD Carry, Name: ImGer#857, MMR: 80, WR: 46.900, Games: 46
# Role: Support, Name: Jeon Heejin simp#SG2, MMR: 88, WR: 50.000, Games: 25
# Role: Mid, Name: 最美味的汤是由不同成分混合制成的#yuz, MMR: 80, WR: 47.500, Games: 47
# Role: Jungler, Name: PocketRocket#SG2, MMR: 79, WR: 46.300, Games: 38
#
# Team MMR: 81 ± 4
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: HellScythez#3438, MMR: 91, WR: 67.000, Games: 71
# Role: Support, Name: Wuang Huei#光辉123, MMR: 90, WR: 65.200, Games: 30
# Role: Mid, Name: CYJS#CYJS, MMR: 90, WR: 64.700, Games: 11
# Role: Jungler, Name: VNeigar#sus, MMR: 90, WR: 60.000, Games: 9
# Role: Top, Name: 诸天系统批发商#SG2, MMR: 90, WR: 62.500, Games: 5
#
# Team MMR: 90 ± 0
#
# Team 2:
# Role: AD Carry, Name: ahyeon#bmn, MMR: 91, WR: 68.800, Games: 22
# Role: Support, Name: Five Pebbles#SG3, MMR: 90, WR: 62.800, Games: 27
# Role: Mid, Name: WOOPER#SG2, MMR: 89, WR: 59.300, Games: 16
# Role: Jungler, Name: Laughing 哥#SG2, MMR: 89, WR: 58.600, Games: 17
# Role: Top, Name: igotyunandme#0101W, MMR: 89, WR: 58.500, Games: 31
#
# Team MMR: 90 ± 1
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Judgm3ntDay#3363, MMR: 44, WR: 55.000, Games: 11
# Role: Top, Name: 春娇与志明#SG2, MMR: 44, WR: 55.700, Games: 64
# Role: Mid, Name: fOrgotteN#1314, MMR: 44, WR: 55.600, Games: 5
# Role: Jungler, Name: InferoOkami#8410, MMR: 44, WR: 55.600, Games: 100
# Role: AD Carry, Name: Vesper#csy, MMR: 44, WR: 53.600, Games: 150
#
# Team MMR: 44 ± 0
#
# Team 2:
# Role: Support, Name: Crazykhai#SG2, MMR: 44, WR: 55.800, Games: 24
# Role: Top, Name: sunny day#yyyyy, MMR: 44, WR: 56.300, Games: 45
# Role: Mid, Name: KnightPyton#SG2, MMR: 44, WR: 54.800, Games: 23
# Role: Jungler, Name: PikachuMan#N19, MMR: 44, WR: 56.300, Games: 36
# Role: AD Carry, Name: Jxzg#SG2, MMR: 44, WR: 53.300, Games: 8
#
# Team MMR: 44 ± 0
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: TheShyhere#7898, MMR: 79, WR: 45.100, Games: 23
# Role: Mid, Name: TESTICULRTORSION#SG2, MMR: 80, WR: 47.500, Games: 29
# Role: AD Carry, Name: SKT Swagwalker#SG2, MMR: 88, WR: 50.000, Games: 5
# Role: Support, Name: peepo#5934, MMR: 80, WR: 47.000, Games: 70
# Role: Top, Name: tokithruster#cunny, MMR: 80, WR: 48.300, Games: 28
#
# Team MMR: 81 ± 3
#
# Team 2:
# Role: Jungler, Name: 点燃手#7105, MMR: 91, WR: 66.700, Games: 4
# Role: Mid, Name: gsgboi#5402, MMR: 80, WR: 49.000, Games: 25
# Role: AD Carry, Name: Flyingracoon4#SG2, MMR: 88, WR: 50.000, Games: 25
# Role: Support, Name: EmoNessLife#0104, MMR: 79, WR: 44.400, Games: 4
# Role: Top, Name: Kokusen#6245, MMR: 80, WR: 47.900, Games: 23
#
# Team MMR: 83 ± 5
#
# MMR Difference: 2
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: Scizor#1448, MMR: 159, WR: 48.100, Games: 38
# Role: AD Carry, Name: Mikazuki#夜刀神, MMR: 160, WR: 49.000, Games: 48
# Role: Mid, Name: half and half#2004, MMR: 159, WR: 47.400, Games: 36
# Role: Support, Name: Axis#H2O, MMR: 154, WR: 31.300, Games: 5
# Role: Top, Name: Rainbowsparky#4748, MMR: 159, WR: 46.800, Games: 22
#
# Team MMR: 158 ± 2
#
# Team 2:
# Role: Jungler, Name: Juweyl#SG2, MMR: 159, WR: 48.300, Games: 14
# Role: AD Carry, Name: LunLunIsVapour#5298, MMR: 157, WR: 41.200, Games: 7
# Role: Mid, Name: Solarix#SG2, MMR: 178, WR: 55.000, Games: 44
# Role: Support, Name: GeorgieDenbrough#SG2, MMR: 134, WR: 57.500, Games: 23
# Role: Top, Name: Kierra Rush#7951, MMR: 176, WR: 51.100, Games: 89
#
# Team MMR: 161 ± 16
#
# MMR Difference: 3
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: Gentle Blade#SG2, MMR: 79, WR: 44.900, Games: 22
# Role: Mid, Name: Treex#6666, MMR: 79, WR: 44.300, Games: 35
# Role: Top, Name: atw2#matt, MMR: 80, WR: 47.200, Games: 25
# Role: Support, Name: XPANDORO#C0YS, MMR: 78, WR: 38.500, Games: 5
# Role: AD Carry, Name: luvsic#sigh, MMR: 79, WR: 42.900, Games: 6
#
# Team MMR: 79 ± 0
#
# Team 2:
# Role: Jungler, Name: Beast#Bing, MMR: 79, WR: 43.800, Games: 14
# Role: Mid, Name: GraveyardKeeper#SG2, MMR: 78, WR: 40.000, Games: 4
# Role: Top, Name: Ninjah#5798, MMR: 80, WR: 47.600, Games: 20
# Role: Support, Name: kafuu#bot, MMR: 88, WR: 50.000, Games: 3
# Role: AD Carry, Name: Unholy#6777, MMR: 77, WR: 29.400, Games: 5
#
# Team MMR: 80 ± 4
#
# MMR Difference: 1
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: Barbatos#6180, MMR: 159, WR: 45.800, Games: 11
# Role: AD Carry, Name: sin#xing, MMR: 159, WR: 47.700, Games: 61
# Role: Top, Name: PIU PIU PIU#2907, MMR: 159, WR: 46.800, Games: 22
# Role: Support, Name: NayeonTAT#4435, MMR: 159, WR: 46.700, Games: 7
# Role: Mid, Name: ojim#ojim, MMR: 160, WR: 49.100, Games: 53
#
# Team MMR: 159 ± 0
#
# Team 2:
# Role: Jungler, Name: ttvhumzh#2276, MMR: 160, WR: 49.400, Games: 41
# Role: AD Carry, Name: 675#half, MMR: 144, WR: 100.000, Games: 8
# Role: Top, Name: slippery snake#0423, MMR: 148, WR: 11.100, Games: 1
# Role: Support, Name: 殺生魚丸#7414, MMR: 181, WR: 64.300, Games: 9
# Role: Mid, Name: Sonavaty#SG2, MMR: 177, WR: 54.500, Games: 84
#
# Team MMR: 162 ± 15
#
# MMR Difference: 3
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Avalanchee#SG2, MMR: 2090, WR: 50.000, Games: 8
# Role: Top, Name: sahpuasz#SG2, MMR: 2104, WR: 53.600, Games: 15
# Role: Mid, Name: glegglie#SG2, MMR: 2084, WR: 63.200, Games: 12
# Role: AD Carry, Name: Miyawaki Sakura#000, MMR: 2077, WR: 61.400, Games: 35
# Role: Jungler, Name: KKayn#SG2, MMR: 2214, WR: 53.500, Games: 23
#
# Team MMR: 2114 ± 51
#
# Team 2:
# Role: Support, Name: Washed ADC#SG2, MMR: 2079, WR: 61.900, Games: 13
# Role: Top, Name: 澳门首家线上赌场上线啦#8783, MMR: 2054, WR: 55.000, Games: 22
# Role: Mid, Name: gahaMoment#1379, MMR: 2063, WR: 57.600, Games: 34
# Role: AD Carry, Name: FallenAquarius#love, MMR: 2058, WR: 56.100, Games: 60
# Role: Jungler, Name: beef boss#beef, MMR: 2435, WR: 53.300, Games: 57
#
# Team MMR: 2138 ± 149
#
# MMR Difference: 24
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: Stop die#SG2, MMR: 118, WR: 42.900, Games: 6
# Role: Jungler, Name: nicky4k#8846, MMR: 132, WR: 51.900, Games: 14
# Role: Top, Name: SlavaY#SG2, MMR: 133, WR: 52.900, Games: 46
# Role: Mid, Name: Inshallah Humans#Akali, MMR: 132, WR: 52.100, Games: 38
# Role: Support, Name: randomuser#1605, MMR: 132, WR: 51.400, Games: 37
#
# Team MMR: 130 ± 6
#
# Team 2:
# Role: AD Carry, Name: Indica#CLOUD, MMR: 120, WR: 48.500, Games: 33
# Role: Jungler, Name: yuris#zhang, MMR: 133, WR: 55.000, Games: 11
# Role: Top, Name: legitaxes#ars, MMR: 138, WR: 76.900, Games: 50
# Role: Mid, Name: SWISS BANKLORD#SG2, MMR: 154, WR: 30.000, Games: 3
# Role: Support, Name: Bork#7344, MMR: 133, WR: 52.500, Games: 32
#
# Team MMR: 136 ± 11
#
# MMR Difference: 6
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Testing with mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, kills, death, assists features:
# Formed teams in 0.016 seconds:
# Team 1:
# Role: Support, Name: Ivernn#SG2, MMR: 157, WR: 40.000, Games: 2
# Role: Mid, Name: T A K A#Eon, MMR: 158, WR: 42.300, Games: 11
# Role: AD Carry, Name: FutureBanner#8192, MMR: 39, WR: 41.100, Games: 23
# Role: Jungler, Name: road to the top#SG2, MMR: 118, WR: 43.400, Games: 23
# Role: Top, Name: oECo#SG2, MMR: 118, WR: 40.000, Games: 6
#
# Team MMR: 118 ± 43
#
# Team 2:
# Role: Support, Name: 超级烦#6339, MMR: 156, WR: 36.400, Games: 8
# Role: Mid, Name: baolin#SG2, MMR: 158, WR: 44.400, Games: 4
# Role: AD Carry, Name: sPeKTRuM1232#BYMP, MMR: 40, WR: 43.800, Games: 7
# Role: Jungler, Name: Money Line#5312, MMR: 39, WR: 43.000, Games: 37
# Role: Top, Name: 我是上帝派来摆烂#0726, MMR: 117, WR: 36.400, Games: 4
#
# Team MMR: 102 ± 53
#
# MMR Difference: 16
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: doodoo1#8888, MMR: 132, WR: 50.600, Games: 85
# Role: Top, Name: RESET#0202, MMR: 176, WR: 50.000, Games: 3
# Role: Jungler, Name: Hosj28#SG2, MMR: 120, WR: 49.400, Games: 41
# Role: Mid, Name: creammx#2710, MMR: 132, WR: 51.800, Games: 114
# Role: AD Carry, Name: SnowMix#SG2, MMR: 159, WR: 48.300, Games: 29
#
# Team MMR: 144 ± 21
#
# Team 2:
# Role: Support, Name: Seraphial#Luu, MMR: 176, WR: 50.600, Games: 42
# Role: Top, Name: seahunter1111#SG2, MMR: 132, WR: 50.000, Games: 9
# Role: Jungler, Name: 我和四个蠢b队友#0305, MMR: 44, WR: 50.900, Games: 88
# Role: Mid, Name: Teralyke#gay, MMR: 88, WR: 52.200, Games: 35
# Role: AD Carry, Name: HorseLiker#6969, MMR: 132, WR: 50.000, Games: 32
#
# Team MMR: 115 ± 45
#
# MMR Difference: 29
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: Sodie#6218, MMR: 90, WR: 60.000, Games: 3
# Role: Top, Name: Lily#697, MMR: 45, WR: 58.600, Games: 68
# Role: Mid, Name: Xeesoxee#XXXXX, MMR: 45, WR: 57.900, Games: 22
# Role: Jungler, Name: BehindYOU223#King, MMR: 45, WR: 60.000, Games: 24
# Role: Support, Name: Izanami#5865, MMR: 89, WR: 59.100, Games: 13
#
# Team MMR: 63 ± 22
#
# Team 2:
# Role: AD Carry, Name: LOSER QUEUE#ATP, MMR: 89, WR: 57.000, Games: 45
# Role: Top, Name: ChromeGenex#SG2, MMR: 45, WR: 60.000, Games: 75
# Role: Mid, Name: Vaxeen#3934, MMR: 45, WR: 58.900, Games: 43
# Role: Jungler, Name: Asline#love, MMR: 45, WR: 58.300, Games: 7
# Role: Support, Name: PsychoJoker#Joker, MMR: 45, WR: 57.600, Games: 19
#
# Team MMR: 54 ± 18
#
# MMR Difference: 9
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: 蛋糕味牛奶つ#520, MMR: 40, WR: 45.000, Games: 27
# Role: Jungler, Name: I am a hero too#hero2, MMR: 40, WR: 45.000, Games: 9
# Role: Top, Name: Kisho Ragia#Pizza, MMR: 40, WR: 45.200, Games: 14
# Role: AD Carry, Name: amugus#6969, MMR: 40, WR: 44.100, Games: 15
# Role: Mid, Name: Treex#6666, MMR: 79, WR: 44.300, Games: 35
#
# Team MMR: 47 ± 16
#
# Team 2:
# Role: Support, Name: 三脚送人头#4996, MMR: 40, WR: 45.500, Games: 10
# Role: Jungler, Name: Kingsley King#SG2, MMR: 160, WR: 48.500, Games: 32
# Role: Top, Name: DrVeggie#2000, MMR: 40, WR: 46.400, Games: 51
# Role: AD Carry, Name: 蒼穹無涯劍法#1928, MMR: 40, WR: 47.400, Games: 55
# Role: Mid, Name: DanLarceny#Ren, MMR: 80, WR: 48.400, Games: 59
#
# Team MMR: 72 ± 47
#
# MMR Difference: 24
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Glasswalker#Akira, MMR: 80, WR: 48.100, Games: 13
# Role: AD Carry, Name: ImGer#857, MMR: 80, WR: 46.900, Games: 46
# Role: Mid, Name: RATBOY24#CNM, MMR: 40, WR: 49.500, Games: 47
# Role: Top, Name: Selling Kidney#DMME, MMR: 40, WR: 48.400, Games: 181
# Role: Jungler, Name: skibidiaurasigma#GYATT, MMR: 44, WR: 50.500, Games: 51
#
# Team MMR: 57 ± 19
#
# Team 2:
# Role: Support, Name: cat wizard#ket, MMR: 79, WR: 45.900, Games: 17
# Role: AD Carry, Name: xXxGodlyxXx#PETRA, MMR: 40, WR: 47.400, Games: 55
# Role: Mid, Name: Natsuu#meow, MMR: 88, WR: 50.000, Games: 30
# Role: Top, Name: Heart#MNG6, MMR: 40, WR: 48.800, Games: 41
# Role: Jungler, Name: InZenous#7589, MMR: 44, WR: 51.200, Games: 129
#
# Team MMR: 58 ± 21
#
# MMR Difference: 2
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: HanAce#SG2, MMR: 180, WR: 61.500, Games: 16
# Role: Top, Name: Heinzki#SG2, MMR: 90, WR: 59.400, Games: 19
# Role: Mid, Name: Fried Bacon#666, MMR: 45, WR: 58.800, Games: 30
# Role: AD Carry, Name: Sobble#1837, MMR: 45, WR: 60.000, Games: 3
# Role: Jungler, Name: Qby#SG2, MMR: 89, WR: 58.800, Games: 10
#
# Team MMR: 90 ± 49
#
# Team 2:
# Role: Support, Name: FK Burger#39777, MMR: 135, WR: 60.900, Games: 28
# Role: Top, Name: ybybyb#SG2, MMR: 45, WR: 62.500, Games: 15
# Role: Mid, Name: weiwei#中国中国, MMR: 45, WR: 58.400, Games: 80
# Role: AD Carry, Name: Envox#UwU, MMR: 45, WR: 60.700, Games: 17
# Role: Jungler, Name: 獸貓393#393, MMR: 45, WR: 56.800, Games: 67
#
# Team MMR: 63 ± 36
#
# MMR Difference: 27
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Top, Name: Nakiri#ay4me, MMR: 150, WR: 20.000, Games: 1
# Role: Mid, Name: T0xiczzz#lzy, MMR: 39, WR: 42.900, Games: 21
# Role: Support, Name: Xixixi98#SG2, MMR: 39, WR: 35.300, Games: 6
# Role: Jungler, Name: Rayn#1517, MMR: 116, WR: 31.800, Games: 7
# Role: AD Carry, Name: Argent#0805, MMR: 116, WR: 32.800, Games: 22
#
# Team MMR: 92 ± 45
#
# Team 2:
# Role: Top, Name: 너의 엄마#한국어, MMR: 38, WR: 25.000, Games: 2
# Role: Mid, Name: Feng Min#4256, MMR: 40, WR: 43.800, Games: 39
# Role: Support, Name: Fat Cats#SG2, MMR: 78, WR: 37.500, Games: 3
# Role: Jungler, Name: Abahmeow#Meow, MMR: 39, WR: 33.300, Games: 2
# Role: AD Carry, Name: 陌生人#SG2, MMR: 39, WR: 33.300, Games: 7
#
# Team MMR: 47 ± 16
#
# MMR Difference: 45
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: Lee King Yuen#SG3, MMR: 2166, WR: 70.000, Games: 49
# Role: AD Carry, Name: σχуgи#8481, MMR: 2286, WR: 71.400, Games: 15
# Role: Top, Name: IntingFren#cheap, MMR: 2221, WR: 69.600, Games: 16
# Role: Mid, Name: Manaka#7653, MMR: 2094, WR: 65.900, Games: 27
# Role: Support, Name: Sara#Keror, MMR: 2129, WR: 60.300, Games: 47
#
# Team MMR: 2179 ± 68
#
# Team 2:
# Role: Jungler, Name: JELI 1000LP ACC#KIRBS, MMR: 2120, WR: 73.100, Games: 38
# Role: AD Carry, Name: DPR LIVE#SG2, MMR: 2242, WR: 60.600, Games: 80
# Role: Top, Name: Vita#1999, MMR: 2122, WR: 58.300, Games: 14
# Role: Mid, Name: Acheron#0320, MMR: 2083, WR: 63.000, Games: 58
# Role: Support, Name: Harmony#1259, MMR: 2062, WR: 57.400, Games: 35
#
# Team MMR: 2126 ± 62
#
# MMR Difference: 53
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: Alessis#SG2, MMR: 88, WR: 50.000, Games: 20
# Role: Mid, Name: vaygao#7626, MMR: 88, WR: 51.400, Games: 19
# Role: Jungler, Name: behold3r#SG2, MMR: 44, WR: 50.000, Games: 20
# Role: Support, Name: Bork#7344, MMR: 133, WR: 52.500, Games: 32
# Role: Top, Name: IsoldeMyKidneys#4skin, MMR: 88, WR: 51.300, Games: 79
#
# Team MMR: 88 ± 28
#
# Team 2:
# Role: AD Carry, Name: unagi ball#2307, MMR: 132, WR: 50.900, Games: 28
# Role: Mid, Name: Alouting#Enarr, MMR: 132, WR: 51.800, Games: 57
# Role: Jungler, Name: IM YuNaBi#0914, MMR: 80, WR: 49.100, Games: 79
# Role: Support, Name: Ochita#0702, MMR: 44, WR: 51.500, Games: 121
# Role: Top, Name: LMT Nékrom#LMT, MMR: 44, WR: 51.900, Games: 42
#
# Team MMR: 87 ± 40
#
# MMR Difference: 2
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: ºωº#ººººº, MMR: 46, WR: 70.000, Games: 7
# Role: Jungler, Name: flaming kirby#rawr, MMR: 45, WR: 62.500, Games: 5
# Role: Top, Name: Nocactivity#SG2, MMR: 45, WR: 65.800, Games: 25
# Role: AD Carry, Name: 199723#BILBO, MMR: 134, WR: 60.000, Games: 51
# Role: Mid, Name: snowy#fat, MMR: 45, WR: 66.700, Games: 24
#
# Team MMR: 63 ± 36
#
# Team 2:
# Role: Support, Name: NaNoUNO#9196, MMR: 91, WR: 70.000, Games: 7
# Role: Jungler, Name: Yamato Endo#devil, MMR: 135, WR: 63.200, Games: 12
# Role: Top, Name: Kaze#1015, MMR: 180, WR: 62.500, Games: 10
# Role: AD Carry, Name: Popsscare#8811, MMR: 89, WR: 55.600, Games: 55
# Role: Mid, Name: Mevolent#1155, MMR: 91, WR: 68.400, Games: 13
#
# Team MMR: 117 ± 36
#
# MMR Difference: 54
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# Testing with mmr, win_rate, games_played, avg_creeps_per_min, avg_gold_per_min, calculated_kda features:
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Top, Name: Himmel#7802, MMR: 88, WR: 52.000, Games: 104
# Role: AD Carry, Name: Elyxis#YENA, MMR: 88, WR: 52.700, Games: 48
# Role: Mid, Name: CRY FOR GANK XD#CRY, MMR: 89, WR: 53.800, Games: 21
# Role: Jungler, Name: Asgarnia#1111, MMR: 44, WR: 53.200, Games: 82
# Role: Support, Name: Delulu#fomo, MMR: 44, WR: 51.900, Games: 14
#
# Team MMR: 71 ± 22
#
# Team 2:
# Role: Top, Name: のろい#curse, MMR: 88, WR: 52.700, Games: 39
# Role: AD Carry, Name: eyyd#2989, MMR: 88, WR: 52.900, Games: 9
# Role: Mid, Name: megu2#1163, MMR: 89, WR: 55.200, Games: 37
# Role: Jungler, Name: Manpee#SG2, MMR: 44, WR: 54.900, Games: 78
# Role: Support, Name: 小Joker#0001, MMR: 44, WR: 51.100, Games: 23
#
# Team MMR: 71 ± 22
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Mid, Name: WSB Espresso#Kopi, MMR: 88, WR: 51.900, Games: 55
# Role: AD Carry, Name: onebigsmiley#2222, MMR: 88, WR: 51.600, Games: 16
# Role: Jungler, Name: coinflip gamer#kcy2, MMR: 88, WR: 52.400, Games: 22
# Role: Support, Name: mini cop#r0b0, MMR: 88, WR: 52.300, Games: 23
# Role: Top, Name: 5K FaZYP#7910, MMR: 88, WR: 52.500, Games: 127
#
# Team MMR: 88 ± 0
#
# Team 2:
# Role: Mid, Name: Kirito Kirigaya#99999, MMR: 89, WR: 53.200, Games: 75
# Role: AD Carry, Name: Lut tut#SG2, MMR: 88, WR: 50.000, Games: 56
# Role: Jungler, Name: The Cake#Cake, MMR: 88, WR: 51.900, Games: 112
# Role: Support, Name: FlareTheDonut#SG2, MMR: 88, WR: 52.600, Games: 10
# Role: Top, Name: woobin238712#23871, MMR: 88, WR: 51.700, Games: 62
#
# Team MMR: 88 ± 0
#
# MMR Difference: 0
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Isekaijoucho#SG2, MMR: 44, WR: 52.900, Games: 9
# Role: Top, Name: CSI 2uak#2uak, MMR: 44, WR: 53.800, Games: 42
# Role: Mid, Name: SnoopyDoo#7777, MMR: 44, WR: 52.200, Games: 83
# Role: AD Carry, Name: seungheon#1234, MMR: 44, WR: 52.500, Games: 52
# Role: Jungler, Name: DCbanana#SG2, MMR: 44, WR: 53.000, Games: 98
#
# Team MMR: 44 ± 0
#
# Team 2:
# Role: Support, Name: summoner 19#SG2, MMR: 88, WR: 52.100, Games: 25
# Role: Top, Name: ThxForCarry#999, MMR: 89, WR: 53.200, Games: 108
# Role: Mid, Name: RUOXI BABY#1314, MMR: 44, WR: 54.900, Games: 50
# Role: AD Carry, Name: Birthday#hehe, MMR: 44, WR: 51.500, Games: 17
# Role: Jungler, Name: The Hun Is Back#Hun, MMR: 44, WR: 53.600, Games: 105
#
# Team MMR: 62 ± 22
#
# MMR Difference: 18
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: kendall roy#333, MMR: 40, WR: 49.700, Games: 76
# Role: Mid, Name: rubber coin#SG2, MMR: 40, WR: 49.500, Games: 53
# Role: Top, Name: T2 Theshy#上路OTP, MMR: 44, WR: 50.000, Games: 6
# Role: AD Carry, Name: NyxAlex#SHAZE, MMR: 40, WR: 48.400, Games: 31
# Role: Jungler, Name: KakashiHenry#8183, MMR: 44, WR: 50.000, Games: 11
#
# Team MMR: 42 ± 2
#
# Team 2:
# Role: Support, Name: Uberstrike222#5037, MMR: 44, WR: 50.000, Games: 6
# Role: Mid, Name: Hae in#2727, MMR: 40, WR: 49.600, Games: 69
# Role: Top, Name: EmakGAming#4016, MMR: 88, WR: 50.000, Games: 47
# Role: AD Carry, Name: xXxGodlyxXx#PETRA, MMR: 40, WR: 47.400, Games: 55
# Role: Jungler, Name: Swift#B00B, MMR: 88, WR: 50.000, Games: 3
#
# Team MMR: 60 ± 23
#
# MMR Difference: 18
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: 人生南北多歧路#hhn1, MMR: 39, WR: 42.400, Games: 14
# Role: Mid, Name: Feng Min#4256, MMR: 40, WR: 43.800, Games: 39
# Role: Top, Name: NeekoNicoNii#069, MMR: 79, WR: 42.900, Games: 9
# Role: AD Carry, Name: hanerys#1818, MMR: 39, WR: 40.000, Games: 10
# Role: Support, Name: Astaroth#4001, MMR: 40, WR: 43.900, Games: 18
#
# Team MMR: 47 ± 16
#
# Team 2:
# Role: Jungler, Name: Sneakysquid#2814, MMR: 39, WR: 42.900, Games: 42
# Role: Mid, Name: D3AN#3361, MMR: 40, WR: 45.200, Games: 19
# Role: Top, Name: Gome#SG2, MMR: 118, WR: 42.900, Games: 21
# Role: AD Carry, Name: Febux#SSR, MMR: 117, WR: 38.500, Games: 15
# Role: Support, Name: Phoen1X#Yuumi, MMR: 79, WR: 46.400, Games: 32
#
# Team MMR: 79 ± 35
#
# MMR Difference: 32
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Support, Name: Rene#i1013, MMR: 45, WR: 66.700, Games: 8
# Role: Jungler, Name: 조이기버#0711, MMR: 45, WR: 64.700, Games: 22
# Role: Mid, Name: Lvance#5285, MMR: 91, WR: 66.700, Games: 6
# Role: Top, Name: foker#11111, MMR: 45, WR: 66.700, Games: 24
# Role: AD Carry, Name: chinguPingu#SG2, MMR: 45, WR: 66.200, Games: 43
#
# Team MMR: 54 ± 18
#
# Team 2:
# Role: Support, Name: Revax#SG2, MMR: 45, WR: 67.400, Games: 29
# Role: Jungler, Name: mobi boots#yippe, MMR: 90, WR: 63.600, Games: 14
# Role: Mid, Name: Ashborn#1337, MMR: 181, WR: 66.700, Games: 14
# Role: Top, Name: Jogoat#elite, MMR: 135, WR: 64.300, Games: 9
# Role: AD Carry, Name: HellScythez#3438, MMR: 91, WR: 67.000, Games: 71
#
# Team MMR: 109 ± 46
#
# MMR Difference: 54
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: DeathWish#SG2, MMR: 44, WR: 50.900, Games: 57
# Role: Support, Name: Ánh Nắng Của Anh#keri, MMR: 44, WR: 50.900, Games: 81
# Role: Top, Name: DSG storm#ACE, MMR: 44, WR: 50.000, Games: 3
# Role: Jungler, Name: SongThrush#biu, MMR: 40, WR: 49.500, Games: 51
# Role: Mid, Name: TikusIRL#1111, MMR: 40, WR: 49.000, Games: 70
#
# Team MMR: 42 ± 2
#
# Team 2:
# Role: AD Carry, Name: haiyaaa#SG2, MMR: 40, WR: 48.500, Games: 16
# Role: Support, Name: shiro boushi#SG2, MMR: 44, WR: 51.500, Games: 35
# Role: Top, Name: EmakGAming#4016, MMR: 88, WR: 50.000, Games: 47
# Role: Jungler, Name: MUTE ALL EZPZ#SG2, MMR: 40, WR: 48.900, Games: 67
# Role: Mid, Name: 悲伤玉米排骨汤#SG2, MMR: 80, WR: 48.700, Games: 19
#
# Team MMR: 58 ± 21
#
# MMR Difference: 16
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: Jungler, Name: BearyPotter#SG2, MMR: 45, WR: 66.700, Games: 14
# Role: AD Carry, Name: Hydrolyze#1540, MMR: 90, WR: 64.700, Games: 11
# Role: Mid, Name: Acnologia#dest, MMR: 136, WR: 66.700, Games: 8
# Role: Top, Name: make you GG#SG2, MMR: 136, WR: 66.700, Games: 10
# Role: Support, Name: CoCo沪上阿姨蜜雪#666, MMR: 45, WR: 61.500, Games: 8
#
# Team MMR: 91 ± 41
#
# Team 2:
# Role: Jungler, Name: xiao long pau#pau, MMR: 91, WR: 66.700, Games: 4
# Role: AD Carry, Name: zEzreal#0001, MMR: 45, WR: 62.500, Games: 5
# Role: Mid, Name: Tommie#4673, MMR: 135, WR: 63.600, Games: 35
# Role: Top, Name: IG TheShy#18 IG, MMR: 45, WR: 64.700, Games: 22
# Role: Support, Name: Izanami#5865, MMR: 89, WR: 59.100, Games: 13
#
# Team MMR: 81 ± 34
#
# MMR Difference: 9
#
# ****************************************************************************************************
# Formed teams in 0.016 seconds:
# Team 1:
# Role: Support, Name: washeduphaiya#801, MMR: 177, WR: 52.700, Games: 78
# Role: Mid, Name: Insect#0527, MMR: 133, WR: 52.500, Games: 32
# Role: Top, Name: Nigyboy#2323, MMR: 132, WR: 51.900, Games: 40
# Role: AD Carry, Name: Faded As Me#1120, MMR: 133, WR: 52.900, Games: 45
# Role: Jungler, Name: 你们看我吊吗#SG2, MMR: 88, WR: 52.300, Games: 56
#
# Team MMR: 133 ± 28
#
# Team 2:
# Role: Support, Name: mini cop#r0b0, MMR: 88, WR: 52.300, Games: 23
# Role: Mid, Name: NoobMaster 68#SG2, MMR: 133, WR: 52.500, Games: 84
# Role: Top, Name: Spear#0130, MMR: 88, WR: 52.100, Games: 37
# Role: AD Carry, Name: Wasabii#baka, MMR: 88, WR: 52.900, Games: 9
# Role: Jungler, Name: 676767#xxs, MMR: 89, WR: 53.300, Games: 8
#
# Team MMR: 97 ± 18
#
# MMR Difference: 35
#
# ****************************************************************************************************
# Formed teams in 0.000 seconds:
# Team 1:
# Role: AD Carry, Name: WGTOWADIO#ORDLO, MMR: 88, WR: 50.000, Games: 3
# Role: Mid, Name: Guohezu#9897, MMR: 120, WR: 49.100, Games: 130
# Role: Top, Name: Fukthebush#KING, MMR: 44, WR: 50.000, Games: 22
# Role: Support, Name: HypnoBeast#9818, MMR: 80, WR: 49.200, Games: 31
# Role: Jungler, Name: No Wing#SG2, MMR: 80, WR: 49.300, Games: 37
#
# Team MMR: 82 ± 24
#
# Team 2:
# Role: AD Carry, Name: Turtle the Cat#6393, MMR: 80, WR: 49.700, Games: 95
# Role: Mid, Name: NeverM0re#1999, MMR: 44, WR: 50.000, Games: 48
# Role: Top, Name: Lilac#2291, MMR: 44, WR: 50.000, Games: 3
# Role: Support, Name: AthenaSG#5683, MMR: 120, WR: 49.100, Games: 27
# Role: Jungler, Name: ANg 3421#SG2, MMR: 88, WR: 50.000, Games: 23
#
# Team MMR: 75 ± 29
#
# MMR Difference: 7
#
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************
# ****************************************************************************************************

# %%
games = pd.read_csv("Games_data_raw.csv")
games_players = pd.read_csv("games_players_data_filtered.csv")

# %%
mmr_scale = 3000.0
games_scale = 1000.0
winrate_scale = 100.0
kills_scale = 100.0
deaths_scale = 100.0
assists_scale = 100.0
creeps_scale = 10.0
gold_scale = 1000.0
kda_scale = 10.0

for i in range(len(games)):
    players = [games.iloc[i]['name'], games.iloc[i]['name 2'], games.iloc[i]['name 3'], games.iloc[i]['name 4'], games.iloc[i]['name 5'], games.iloc[i]['name 6'], games.iloc[i]['name 7'], games.iloc[i]['name 8'], games.iloc[i]['name 9'], games.iloc[i]['name 10']]
    game_matrix = []
    for player in players:
        for j in range(len(games_players)):
            if player == games_players.iloc[j]['username']:
                player = games_players.iloc[j]
                player = Player(
                    id=player.username,
                    mmr= None ,
                    win_rate=player.winrate,
                    games_played=player.games_won, #NOT PLAYED
                    role=player.most_played_role,
                    rank=player.rank,
                    division=player.division,
                    lp=player.lp,
                    kills=player.kills,
                    death=player.death,
                    assists=player.assists,
                    avg_creeps_per_min=player.avg_creeps_per_min,
                    avg_gold_per_min=player.avg_gold_per_min,
                    calculated_kda = None
                )
                player.mmr = calculate_mmr(player.__dict__)
                player.calculated_kda = calculate_kda(player.__dict__)
                game_matrix.append([player.mmr/mmr_scale, player.win_rate/winrate_scale, player.games_played/games_scale, player.calculated_kda/kda_scale, player.avg_creeps_per_min/creeps_scale, player.avg_gold_per_min/gold_scale])
    game_matrix = np.array(game_matrix)
    print(game_matrix)
    #calculate variance between the different players stats
    variance = np.var(game_matrix, axis=0)
    print(variance)
    #calculate the norm of the variance
    norm = np.linalg.norm(variance)
    print(norm)
    

    break
# Out:
# [[0.80696    0.502      0.108      0.3        0.72       0.42424   ]
#  [0.81121333 0.531      0.113      0.226      0.722      0.43884   ]
#  [0.81341333 0.546      0.107      0.402      0.682      0.4302    ]
#  [0.81854667 0.581      0.091      0.492      0.73       0.45562   ]
#  [0.81781333 0.576      0.034      0.248      0.664      0.40106   ]
#  [0.82309333 0.612      0.041      0.395      0.786      0.4505    ]
#  [0.81136    0.532      0.267      0.376      0.75       0.47474   ]
#  [0.81018667 0.524      0.111      0.385      0.77       0.45194   ]
#  [0.6672     0.56       0.028      0.374      0.664      0.47062   ]
#  [0.8162     0.565      0.048      0.731      0.104      0.29546   ]]
# [0.00196782 0.00094029 0.00438276 0.01824069 0.03580656 0.0024255 ]
# 0.040554661581033526
